# %% [markdown]
# # Task:
#  - ## Create a GUI app by tkinter.
#  - ## Two functionalities:
#      - ### 1st: Scan; search for the input entered by scanning all directories or desired one and return all file names similar to the input.
#      - ### 2nd: Merge; copy the data from all the files of desired extension and dump into one single file having the same extension.
#
# ### Note: there's a catch in my logicality i.e. in this GUI if you want to search for any specific extension, you'd have to enter it properly--what I mean to say is if you enter '.doc', you won't get any results for '.docx' and the same goes for vice-versa.

# %%
from tkinter import *
from tkinter import messagebox
import os, logging as lg, docx, PyPDF2

# %%
class Log:
    def __init__(self):
        try:
            self.logFile="SearchandMerge.log"
            if os.path.exists(self.logFile):
                os.remove(self.logFile)
            lg.basicConfig(filename=self.logFile, level=lg.INFO, format="%(asctime)s %(levelname)s %(message)s")
            #Adding the StreamHandler to record logs in the console.
            self.console_log = lg.StreamHandler()
            self.console_log.setLevel(lg.INFO) #setting level to the console log.
            self.format = lg.Formatter("%(asctime)s %(message)s")
            self.console_log.setFormatter(self.format) #defining format for the console log.
            lg.getLogger('').addHandler(self.console_log) #adding handler to the console log.
        
        except Exception as e:
            lg.info(e)
            
        else:
            lg.info("Log Class successfully executed!")

# %%
class GUI:
    def __init__(self):
        """
        Whole layout of our desired wibdow is set here as wwe know __init__ function will be 
        automatically called the moment we create its object.
        """
        self.win = Tk()
        self.win.title("Search & Merge")
        
        #directories
        self.drive = ""
        self.drives = self.__mydrives()
        
        #a dict that stores filenames and their roots as well.
        self.fileRoot = {}
        #current dir where merged files will be created
        self.curDir = os.getcwd()
        
        try:
            #row0
            self.prompt = "Enter the desired drive from (C, D, E or G) \nOR\n Enter 'scan all' or 'search all' if you so much want so: "
            self.l = Label(self.win, text = self.prompt)
            self.l.grid(row=0, column=0)

            #row1
            self.searchInput = Entry(self.win, borderwidth=3, width=125) #search input
            self.searchInput.grid(row=1, column=0)
            self.chooseDrive = Button(self.win, text="select Drive", padx=8, pady=3, command=self.__choosedrive).grid(row=1, column=1) #fro choosing dir

            #row2
            self.l2 = Label(self.win)
            self.l2.grid(row = 2, column = 0) #what directory has been chosen.

            #row3
            self.searchFor = Button(self.win, text="search", padx=10, pady=5, command=self.__search_for)
            self.searchFor.grid(row = 3, column = 0)

            #row4
            self.l4 = Label(self.win)
            self.l4.grid(row = 4, column = 0)

            #row5
            self.searchRes = Text(self.win, borderwidth=2, width=110) #search results
            self.searchRes.grid(row=5, column=0, columnspan=4)
            self.searchRes.config(state="disabled") #so that nothing couldn't be typed into it externally.
            #adding a vertical scroll bar.
            self.vsbar = Scrollbar(self.win, orient='vertical')
            self.vsbar.grid(row = 5, column = 3, sticky = 'e')
            self.vsbar.config(command=self.searchRes.yview)

            #row6
            self.merger = Button(self.win, text="Merge (.txt, .docx or .pdf)", padx=8, pady=3, command=self.__merge).grid(row = 6, column = 0)
        except Exception as e:
            lg.error(e)
        finally:
            self.win.mainloop()
            
    def __mydrives(self):
        """
        Will return the list of available drives on this pc.
        """
        try:
            import string
            alphas = string.ascii_uppercase #generating all alphabets.
            dri = []
            dri+=alphas
            mydrives = [] #will contain available drives of this system.
            for i in dri:
                if os.path.exists(i+"://"):
                    mydrives.append(i)
            return mydrives
        except Exception as e:
            lg.error(e)            
        
        
    def __choosedrive(self):
        """
        Will assist in choosing a directory.
        """
        try:
            self.l2.config(text = "") #truncating this label everytime this button is triggered.
            self.drive = self.searchInput.get().capitalize()

            if self.drive in self.drives:
                self.l2.config(text = f"Your desired drive {self.drive} will be scanned!\nNow, enter search input..")
                self.searchInput.delete(0, END)
                return self.drive

            elif self.drive == "Search all" or self.drive == "Scan all":
                self.l2.config(text = "All drives will be scanned!\nNow, enter search input..")
                self.searchInput.delete(0, END)
                return self.drive
            
            elif len(self.drive)==0:
                messagebox.showwarning("No drive selected!", "for the least part, try choosing a drive..")
                lg.error("No drive selected!")
            else:
                messagebox.showerror("No such drive found!", "Enter an appropriate drive, my man!")
                lg.error("An appropriate drive needs to be chosen!")
                self.searchInput.delete(0, END)
        except Exception as e:
            lg.error(e)
    
    def __search_for(self): #functionality for search button.
        try:
            self.fileRoot = {} #truncating the dict every time search button is hit.
            s = self.searchInput.get() #searchable i.e. we'll search for it.
            self.searchInput.delete(0, END)
            
            if self.l2["text"] == "": #i.e. no drive selected and search button is hit.
                messagebox.showwarning("no drive selected!", "for the least part, try choosing a drive..")
                lg.error("No drive selected!")
                return 0
                
            if len(s) == 0: #if nothing is entered.
                messagebox.showwarning("no search input!", "to get some results and in order to merge them, something oughta be entered!")
                lg.error("to get some results and in order to merge them, something oughta be entered!")
                return 0 #to not further advance in this function.
            
            #Clearing the prior search results if any before searching again.
            self.searchRes.config(state="normal")
            self.searchRes.delete(1.0, END) 
            self.searchRes.config(state="disabled")
            
            self.l4.config(text = f"search results for '{s}'..")

            if self.drive == "Scan all" or self.drive == "Search all": #If all directories are to be searched.
                
                lg.info("All drives are being scanned..")
                lg.info("generating search results...")
                
                disks = [i+"://" for i in self.drives] #a list containing drives with their paths.
                for d in disks:
                    for root, dirs, files in os.walk(d, topdown=True): 
                        for i in files:
                            if s.startswith("."): #search input is an extension
                                if i.endswith(s):
                                    self.searchRes.config(state="normal")
                                    self.searchRes.insert(END, i)
                                    self.searchRes.insert(END, '\n')
                                    self.searchRes.config(state="disabled")
                                    
                                    self.fileRoot[i] = root #adding filename and its root as well to fileRoot{}.
                                    lg.info(i)
                            else:
                                if i.startswith(s) or s in i: 
                                    """
                                    if filenames start with search input or search input is present anywhere in between in filenames.
                                    """
                                    self.searchRes.config(state="normal")
                                    self.searchRes.insert(END, i)
                                    self.searchRes.insert(END, '\n')
                                    self.searchRes.config(state="disabled")
                                    
                                    self.fileRoot[i] = root #adding filename and its root as well to fileRoot{}.
                                    lg.info(i)
                if len(self.searchRes.get("1.0", END))==1:
                    messagebox.showinfo("nothing found!", "try entering some different input to be searched, No results found!")
                    lg.info("No results found!")

            else: #if single directory is to be searched.
                
                lg.info(f"Drive {self.drive} is being scanned..")
                lg.info("generating search results...")
                
                for root, dirs, files in os.walk(f'{self.drive}://', topdown=True):
                    for i in files:
                        if s.startswith("."): #search input is an extension
                            if i.endswith(s):
                                
                                self.searchRes.config(state="normal")
                                self.searchRes.insert(END, i)
                                self.searchRes.insert(END, '\n')
                                self.searchRes.config(state="disabled")
                                
                                self.fileRoot[i] = root #adding filename and its root as well to fileRoot{}.
                                lg.info(i)
                        else:
                            if i.startswith(s) or s in i: 
                                """
                                if filenames start with search input or search input is present anywhere in between in filenames.
                                """
                                
                                self.searchRes.config(state="normal")
                                self.searchRes.insert(END, i)
                                self.searchRes.insert(END, '\n')
                                self.searchRes.config(state="disabled")
                                
                                self.fileRoot[i] = root #adding filename and its root as well to fileRoot{}.
                                lg.info(i)
                if len(self.searchRes.get("1.0", END))==1:
                    messagebox.showinfo("nothing found!", "try entering some different input to be searched, No results found!")
                    lg.info("No results found!")

        except Exception as e:
            lg.error(e)     
        else:
            lg.info("search results generated!")
            lg.info("-------------------------")
            
    def __merge(self):
        global content
        content = [i for i in self.fileRoot.keys()]
        
        try:
            if ".txt" in content[0]:

                txt_file="txt(Merged).txt"
                if os.path.exists(txt_file):
                    os.remove(txt_file)

                for i in content: #parsing each .txt file contained in the 'content'.
                    if i==txt_file: #skipping the merged file that is meant to be truncated everytime.
                        continue
                    os.chdir(self.fileRoot[i]) #going to the dir where the file is.

                    with open(i, "r+", encoding='utf-8') as f:
                        data = f.readlines()
                        f.close()
                        
                    os.chdir(self.curDir) #coming back to our original directory.
                    with open(txt_file, "a+") as g:
                        g.writelines(i)
                        g.write("\n")
                        g.write("\n")
                        g.writelines(data)
                        g.write("\n")
                        g.write("\n")
                        
                g.close()
                messagebox.showinfo("file ready!", "Merged '.txt' is ready! You can check it now.")
                lg.info(f"Merged '.txt' is ready! You can check it now.")

            elif ".docx" in content[0]:
                docx_file = "docx(Merged).docx"
                if os.path.exists(docx_file):
                    os.remove(docx_file)

                merged = docx.Document() #creating our merged .docx file
                for i in content:
                    if i==docx_file: #to skip the file we are creating, if it has already been lying there.
                        continue
                    os.chdir(self.fileRoot[i]) #going to the dir where the file to be copied is. 
                    doc = docx.Document(i)
                    os.chdir(self.curDir) #returning to our original dir.
                    merged.add_heading(i)
                    merged.add_paragraph("\n")
                    for j in range(len(doc.paragraphs)):
                        merged.add_paragraph(doc.paragraphs[j].text)
                    merged.add_paragraph("\n") 
                merged.save(docx_file)
                messagebox.showinfo("file ready!", "Merged '.docx' is ready! You can check it now.")
                lg.info(f"Merged '.docx' is ready! You can check it now.")

            elif ".pdf" in content[0]:
                pdf_file = "pdf(Merged).pdf"
                if os.path.exists(pdf_file): #deleting the merged pdf if it already exists.
                    os.remove(pdf_file)
                    
                merged = PyPDF2.PdfMerger() #creating a merger object.
                for i in content:
                    if i==pdf_file:
                        continue
                    os.chdir(self.fileRoot[i])
                    #if the file is encrypted
                    reader = PyPDF2.PdfReader(i)
                    if reader.is_encrypted:
                        continue
                    else:    
                        merged.append(i) #appending .pdf to the merger.
                os.chdir(self.curDir) #getting back to our orignal dir.
                merged.write(pdf_file)
                merged.close()
                messagebox.showinfo("file ready!", "Merged '.pdf' is ready! You can check it now.")
                lg.info("Merged '.pdf' is ready! You can check it now.")
                
            else:
                messagebox.showinfo("non-mergeable extension!", "files of the entered extension couldn't be merged..")
                lg.info("files of the entered extension coudn't be merged..")

        except Exception as e:
            lg.error(e)

# %%
Log()
guiApp = GUI()
guiApp
# Out:
# 2022-06-11 20:00:47,470 Log Class successfully executed!
# 2022-06-11 20:01:00,632 Drive C is being scanned..
# 2022-06-11 20:01:00,632 generating search results...
# 2022-06-11 20:01:00,643 hwcompat.txt
# 2022-06-11 20:01:00,645 hwcompatPE.txt
# 2022-06-11 20:01:00,648 hwexclude.txt
# 2022-06-11 20:01:00,651 hwexcludePE.txt
# 2022-06-11 20:01:00,653 idwbinfo.txt
# 2022-06-11 20:01:00,681 erofflps.txt
# 2022-06-11 20:01:00,731 oobe1.txt
# 2022-06-11 20:01:00,733 sub1.txt
# 2022-06-11 20:01:00,736 oobe4.txt
# 2022-06-11 20:01:00,738 sub4.txt
# 2022-06-11 20:01:00,765 NetflixChannelIdHP.txt
# 2022-06-11 20:01:00,767 CustomDataHP.txt
# 2022-06-11 20:01:00,770 PASS1_ML2.txt
# 2022-06-11 20:01:00,781 dummy.txt
# 2022-06-11 20:01:00,798 vollist.txt
# 2022-06-11 20:01:00,858 CASSANDRA-14092.txt
# 2022-06-11 20:01:00,859 CHANGES.txt
# 2022-06-11 20:01:00,860 LICENSE.txt
# 2022-06-11 20:01:00,861 NEWS.txt
# 2022-06-11 20:01:00,862 NOTICE.txt
# 2022-06-11 20:01:00,865 README.txt
# 2022-06-11 20:01:00,867 README.txt
# 2022-06-11 20:01:00,877 me-5-big-TOC.txt
# 2022-06-11 20:01:00,882 me-41-big-TOC.txt
# 2022-06-11 20:01:00,893 me-5-big-TOC.txt
# 2022-06-11 20:01:00,894 me-6-big-TOC.txt
# 2022-06-11 20:01:00,896 me-7-big-TOC.txt
# 2022-06-11 20:01:00,899 me-5-big-TOC.txt
# 2022-06-11 20:01:00,900 me-6-big-TOC.txt
# 2022-06-11 20:01:00,902 me-7-big-TOC.txt
# 2022-06-11 20:01:00,907 me-1-big-TOC.txt
# 2022-06-11 20:01:00,916 me-1-big-TOC.txt
# 2022-06-11 20:01:00,917 me-2-big-TOC.txt
# 2022-06-11 20:01:00,919 me-3-big-TOC.txt
# 2022-06-11 20:01:00,921 me-1-big-TOC.txt
# 2022-06-11 20:01:00,923 me-2-big-TOC.txt
# 2022-06-11 20:01:00,924 me-3-big-TOC.txt
# 2022-06-11 20:01:00,927 me-1-big-TOC.txt
# 2022-06-11 20:01:00,928 me-2-big-TOC.txt
# 2022-06-11 20:01:00,929 me-3-big-TOC.txt
# 2022-06-11 20:01:00,933 me-1-big-TOC.txt
# 2022-06-11 20:01:00,934 me-2-big-TOC.txt
# 2022-06-11 20:01:00,936 me-3-big-TOC.txt
# 2022-06-11 20:01:00,939 me-1-big-TOC.txt
# 2022-06-11 20:01:00,940 me-2-big-TOC.txt
# 2022-06-11 20:01:00,941 me-3-big-TOC.txt
# 2022-06-11 20:01:00,944 me-5-big-TOC.txt
# 2022-06-11 20:01:00,948 me-1-big-TOC.txt
# 2022-06-11 20:01:00,950 me-2-big-TOC.txt
# 2022-06-11 20:01:00,951 me-3-big-TOC.txt
# 2022-06-11 20:01:00,954 me-1-big-TOC.txt
# 2022-06-11 20:01:00,955 me-2-big-TOC.txt
# 2022-06-11 20:01:00,956 me-3-big-TOC.txt
# 2022-06-11 20:01:00,960 me-1-big-TOC.txt
# 2022-06-11 20:01:00,962 me-2-big-TOC.txt
# 2022-06-11 20:01:00,963 me-3-big-TOC.txt
# 2022-06-11 20:01:00,966 me-1-big-TOC.txt
# 2022-06-11 20:01:00,967 me-2-big-TOC.txt
# 2022-06-11 20:01:00,968 me-3-big-TOC.txt
# 2022-06-11 20:01:00,978 requirements.txt
# 2022-06-11 20:01:00,988 aswClnTg.txt
# 2022-06-11 20:01:00,989 aswInfTg.txt
# 2022-06-11 20:01:01,011 list_d.txt
# 2022-06-11 20:01:01,012 list_i.txt
# 2022-06-11 20:01:01,043 Boost.txt
# 2022-06-11 20:01:01,044 brotli.txt
# 2022-06-11 20:01:01,046 bsdiff.txt
# 2022-06-11 20:01:01,048 bzip2.txt
# 2022-06-11 20:01:01,050 c-ares.txt
# 2022-06-11 20:01:01,051 cef.txt
# 2022-06-11 20:01:01,053 Crypto++.txt
# 2022-06-11 20:01:01,055 cURL.txt
# 2022-06-11 20:01:01,056 Detours.txt
# 2022-06-11 20:01:01,058 dnscrypt-proxy.txt
# 2022-06-11 20:01:01,059 EULA.txt
# 2022-06-11 20:01:01,062 GSL.txt
# 2022-06-11 20:01:01,063 ICU.txt
# 2022-06-11 20:01:01,065 intel_asm.txt
# 2022-06-11 20:01:01,067 jansson.txt
# 2022-06-11 20:01:01,068 JsonCpp.txt
# 2022-06-11 20:01:01,070 lexbor.txt
# 2022-06-11 20:01:01,071 libevent.txt
# 2022-06-11 20:01:01,073 libPNG.txt
# 2022-06-11 20:01:01,074 libsodium.txt
# 2022-06-11 20:01:01,076 LUA.txt
# 2022-06-11 20:01:01,078 lzfse.txt
# 2022-06-11 20:01:01,080 LZMA.txt
# 2022-06-11 20:01:01,081 mbedTLS.txt
# 2022-06-11 20:01:01,083 mhook.txt
# 2022-06-11 20:01:01,084 nanopb.txt
# 2022-06-11 20:01:01,085 nghttp2.txt
# 2022-06-11 20:01:01,086 OpenSSL.txt
# 2022-06-11 20:01:01,087 PCRE.txt
# 2022-06-11 20:01:01,089 protobuf.txt
# 2022-06-11 20:01:01,091 pugixml.txt
# 2022-06-11 20:01:01,093 rapidjson.txt
# 2022-06-11 20:01:01,094 sqlite.txt
# 2022-06-11 20:01:01,096 unrar.txt
# 2022-06-11 20:01:01,097 vxWidgets.txt
# 2022-06-11 20:01:01,099 Xerces.txt
# 2022-06-11 20:01:01,099 xmlParser.txt
# 2022-06-11 20:01:01,100 xxHash.txt
# 2022-06-11 20:01:01,102 yara.txt
# 2022-06-11 20:01:01,103 zlib.txt
# 2022-06-11 20:01:01,109 Stats.txt
# 2022-06-11 20:01:01,140 signlic.txt
# 2022-06-11 20:01:01,142 datbit_legal.txt
# 2022-06-11 20:01:01,151 signlic.txt
# 2022-06-11 20:01:01,154 license.txt
# 2022-06-11 20:01:01,159 license.txt
# 2022-06-11 20:01:01,165 log.txt
# 2022-06-11 20:01:01,167 log.txt
# 2022-06-11 20:01:01,195 RPTScanner.txt
# 2022-06-11 20:01:01,289 ThirdPartyNotices.MSHWLatin.txt
# 2022-06-11 20:01:01,433 Readme.txt
# 2022-06-11 20:01:01,439 THIRDPARTYLICENSEREADME-JAVAFX.txt
# 2022-06-11 20:01:01,440 THIRDPARTYLICENSEREADME.txt
# 2022-06-11 20:01:01,445 README.txt
# 2022-06-11 20:01:01,447 THIRDPARTYLICENSEREADME-JAVAFX.txt
# 2022-06-11 20:01:01,449 THIRDPARTYLICENSEREADME.txt
# 2022-06-11 20:01:01,456 Xusage.txt
# 2022-06-11 20:01:01,458 jvm.hprof.txt
# 2022-06-11 20:01:01,469 THIRDPARTYLICENSEREADME.txt
# 2022-06-11 20:01:01,485 asl-v20.txt
# 2022-06-11 20:01:01,488 asl-v20.txt
# 2022-06-11 20:01:01,492 asl-v20.txt
# 2022-06-11 20:01:01,528 VERSION.txt
# 2022-06-11 20:01:01,550 VERSION.txt
# 2022-06-11 20:01:01,567 README.txt
# 2022-06-11 20:01:01,569 THIRDPARTYLICENSEREADME-JAVAFX.txt
# 2022-06-11 20:01:01,571 THIRDPARTYLICENSEREADME.txt
# 2022-06-11 20:01:01,578 Xusage.txt
# 2022-06-11 20:01:01,581 jvm.hprof.txt
# 2022-06-11 20:01:01,594 license.txt
# 2022-06-11 20:01:01,595 scriptversion.txt
# 2022-06-11 20:01:01,603 license.txt
# 2022-06-11 20:01:01,609 license.txt
# 2022-06-11 20:01:01,611 mscdfoem_updater.txt
# 2022-06-11 20:01:01,613 subst_updater.txt
# 2022-06-11 20:01:01,680 LICENSE-Community.txt
# 2022-06-11 20:01:01,694 LICENSE.txt
# 2022-06-11 20:01:01,696 README.txt
# 2022-06-11 20:01:01,704 ChangeLog.txt
# 2022-06-11 20:01:01,705 LICENSE.txt
# 2022-06-11 20:01:01,707 README.txt
# 2022-06-11 20:01:01,711 CHANGES.txt
# 2022-06-11 20:01:01,712 LICENSE.txt
# 2022-06-11 20:01:01,713 README.txt
# 2022-06-11 20:01:01,733 dictionary.txt
# 2022-06-11 20:01:01,734 messages_to_clients.txt
# 2022-06-11 20:01:01,735 messages_to_error_log.txt
# 2022-06-11 20:01:01,748 LICENSE.txt
# 2022-06-11 20:01:01,750 README.txt
# 2022-06-11 20:01:01,776 CREDITS.txt
# 2022-06-11 20:01:01,778 extend.txt
# 2022-06-11 20:01:01,779 HISTORY.txt
# 2022-06-11 20:01:01,781 NEWS.txt
# 2022-06-11 20:01:01,783 NEWS2x.txt
# 2022-06-11 20:01:01,784 README.txt
# 2022-06-11 20:01:01,785 TODO.txt
# 2022-06-11 20:01:01,787 README.txt
# 2022-06-11 20:01:01,790 README.txt
# 2022-06-11 20:01:01,798 Grammar.txt
# 2022-06-11 20:01:01,799 PatternGrammar.txt
# 2022-06-11 20:01:01,808 README.txt
# 2022-06-11 20:01:01,811 top_level.txt
# 2022-06-11 20:01:01,815 top_level.txt
# 2022-06-11 20:01:01,818 entry_points.txt
# 2022-06-11 20:01:01,819 top_level.txt
# 2022-06-11 20:01:01,821 top_level.txt
# 2022-06-11 20:01:01,836 top_level.txt
# 2022-06-11 20:01:02,286 LICENSE.txt
# 2022-06-11 20:01:02,287 THIRD_PARTY_LICENSES.txt
# 2022-06-11 20:01:02,288 top_level.txt
# 2022-06-11 20:01:02,294 top_level.txt
# 2022-06-11 20:01:02,317 vendor.txt
# 2022-06-11 20:01:02,354 entry_points.txt
# 2022-06-11 20:01:02,356 LICENSE.txt
# 2022-06-11 20:01:02,357 top_level.txt
# 2022-06-11 20:01:02,368 top_level.txt
# 2022-06-11 20:01:02,371 top_level.txt
# 2022-06-11 20:01:02,374 top_level.txt
# 2022-06-11 20:01:02,376 top_level.txt
# 2022-06-11 20:01:02,402 LICENSE.txt
# 2022-06-11 20:01:02,404 top_level.txt
# 2022-06-11 20:01:02,407 top_level.txt
# 2022-06-11 20:01:02,420 entry_points.txt
# 2022-06-11 20:01:02,421 top_level.txt
# 2022-06-11 20:01:02,424 top_level.txt
# 2022-06-11 20:01:02,427 header01.txt
# 2022-06-11 20:01:02,429 header02.txt
# 2022-06-11 20:01:02,430 header03.txt
# 2022-06-11 20:01:02,433 top_level.txt
# 2022-06-11 20:01:02,474 cmath_testcases.txt
# 2022-06-11 20:01:02,475 exception_hierarchy.txt
# 2022-06-11 20:01:02,477 floating_points.txt
# 2022-06-11 20:01:02,478 formatfloat_testcases.txt
# 2022-06-11 20:01:02,479 ieee754.txt
# 2022-06-11 20:01:02,480 mailcap.txt
# 2022-06-11 20:01:02,481 math_testcases.txt
# 2022-06-11 20:01:02,482 test_doctest.txt
# 2022-06-11 20:01:02,483 test_doctest2.txt
# 2022-06-11 20:01:02,484 test_doctest3.txt
# 2022-06-11 20:01:02,485 test_doctest4.txt
# 2022-06-11 20:01:02,487 tokenize_tests-latin1-coding-cookie-and-utf8-bom-sig.txt
# 2022-06-11 20:01:02,488 tokenize_tests-no-coding-cookie-and-utf8-bom-sig-only.txt
# 2022-06-11 20:01:02,489 tokenize_tests-utf8-coding-cookie-and-no-utf8-bom-sig.txt
# 2022-06-11 20:01:02,491 tokenize_tests-utf8-coding-cookie-and-utf8-bom-sig.txt
# 2022-06-11 20:01:02,492 tokenize_tests.txt
# 2022-06-11 20:01:02,497 big5-utf8.txt
# 2022-06-11 20:01:02,498 big5.txt
# 2022-06-11 20:01:02,500 big5hkscs-utf8.txt
# 2022-06-11 20:01:02,501 big5hkscs.txt
# 2022-06-11 20:01:02,502 cp949-utf8.txt
# 2022-06-11 20:01:02,504 cp949.txt
# 2022-06-11 20:01:02,505 euc_jisx0213-utf8.txt
# 2022-06-11 20:01:02,506 euc_jisx0213.txt
# 2022-06-11 20:01:02,507 euc_jp-utf8.txt
# 2022-06-11 20:01:02,508 euc_jp.txt
# 2022-06-11 20:01:02,510 euc_kr-utf8.txt
# 2022-06-11 20:01:02,512 euc_kr.txt
# 2022-06-11 20:01:02,514 gb18030-utf8.txt
# 2022-06-11 20:01:02,515 gb18030.txt
# 2022-06-11 20:01:02,517 gb2312-utf8.txt
# 2022-06-11 20:01:02,519 gb2312.txt
# 2022-06-11 20:01:02,520 gbk-utf8.txt
# 2022-06-11 20:01:02,521 gbk.txt
# 2022-06-11 20:01:02,523 hz-utf8.txt
# 2022-06-11 20:01:02,524 hz.txt
# 2022-06-11 20:01:02,526 iso2022_jp-utf8.txt
# 2022-06-11 20:01:02,527 iso2022_jp.txt
# 2022-06-11 20:01:02,528 iso2022_kr-utf8.txt
# 2022-06-11 20:01:02,529 iso2022_kr.txt
# 2022-06-11 20:01:02,532 johab-utf8.txt
# 2022-06-11 20:01:02,534 johab.txt
# 2022-06-11 20:01:02,536 shift_jis-utf8.txt
# 2022-06-11 20:01:02,537 shift_jis.txt
# 2022-06-11 20:01:02,538 shift_jisx0213-utf8.txt
# 2022-06-11 20:01:02,539 shift_jisx0213.txt
# 2022-06-11 20:01:02,552 README.txt
# 2022-06-11 20:01:02,559 msg_01.txt
# 2022-06-11 20:01:02,560 msg_02.txt
# 2022-06-11 20:01:02,562 msg_03.txt
# 2022-06-11 20:01:02,565 msg_04.txt
# 2022-06-11 20:01:02,566 msg_05.txt
# 2022-06-11 20:01:02,568 msg_06.txt
# 2022-06-11 20:01:02,569 msg_07.txt
# 2022-06-11 20:01:02,571 msg_08.txt
# 2022-06-11 20:01:02,573 msg_09.txt
# 2022-06-11 20:01:02,574 msg_10.txt
# 2022-06-11 20:01:02,576 msg_11.txt
# 2022-06-11 20:01:02,577 msg_12.txt
# 2022-06-11 20:01:02,578 msg_12a.txt
# 2022-06-11 20:01:02,581 msg_13.txt
# 2022-06-11 20:01:02,583 msg_14.txt
# 2022-06-11 20:01:02,584 msg_15.txt
# 2022-06-11 20:01:02,585 msg_16.txt
# 2022-06-11 20:01:02,587 msg_17.txt
# 2022-06-11 20:01:02,588 msg_18.txt
# 2022-06-11 20:01:02,590 msg_19.txt
# 2022-06-11 20:01:02,591 msg_20.txt
# 2022-06-11 20:01:02,592 msg_21.txt
# 2022-06-11 20:01:02,593 msg_22.txt
# 2022-06-11 20:01:02,595 msg_23.txt
# 2022-06-11 20:01:02,596 msg_24.txt
# 2022-06-11 20:01:02,599 msg_25.txt
# 2022-06-11 20:01:02,600 msg_26.txt
# 2022-06-11 20:01:02,601 msg_27.txt
# 2022-06-11 20:01:02,602 msg_28.txt
# 2022-06-11 20:01:02,604 msg_29.txt
# 2022-06-11 20:01:02,605 msg_30.txt
# 2022-06-11 20:01:02,612 msg_31.txt
# 2022-06-11 20:01:02,614 msg_32.txt
# 2022-06-11 20:01:02,616 msg_33.txt
# 2022-06-11 20:01:02,617 msg_34.txt
# 2022-06-11 20:01:02,619 msg_35.txt
# 2022-06-11 20:01:02,621 msg_36.txt
# 2022-06-11 20:01:02,623 msg_37.txt
# 2022-06-11 20:01:02,624 msg_38.txt
# 2022-06-11 20:01:02,626 msg_39.txt
# 2022-06-11 20:01:02,628 msg_40.txt
# 2022-06-11 20:01:02,630 msg_41.txt
# 2022-06-11 20:01:02,633 msg_42.txt
# 2022-06-11 20:01:02,634 msg_43.txt
# 2022-06-11 20:01:02,635 msg_44.txt
# 2022-06-11 20:01:02,636 msg_45.txt
# 2022-06-11 20:01:02,638 msg_46.txt
# 2022-06-11 20:01:02,654 resource1.txt
# 2022-06-11 20:01:02,656 resource2.txt
# 2022-06-11 20:01:02,660 resource1.txt
# 2022-06-11 20:01:02,693 world.txt
# 2022-06-11 20:01:02,722 License.txt
# 2022-06-11 20:01:02,724 shell_snippets.py.txt
# 2022-06-11 20:01:02,831 eer_model_object_grt.py.txt
# 2022-06-11 20:01:02,832 eer_model_utility_grt.py.txt
# 2022-06-11 20:01:02,834 generic_grt.py.txt
# 2022-06-11 20:01:02,835 sql_editor_catalog_grt.py.txt
# 2022-06-11 20:01:02,837 sql_editor_filter_grt.py.txt
# 2022-06-11 20:01:02,838 sql_editor_resultset_grt.py.txt
# 2022-06-11 20:01:02,839 sql_editor_utility_grt.py.txt
# 2022-06-11 20:01:02,841 DB Management.txt
# 2022-06-11 20:01:02,842 SQL DDL Statements.txt
# 2022-06-11 20:01:02,844 SQL DML Statements.txt
# 2022-06-11 20:01:02,860 LICENSE.txt
# 2022-06-11 20:01:02,861 README.txt
# 2022-06-11 20:01:02,868 OSSNotice.txt
# 2022-06-11 20:01:02,919 2.dc6d7670.chunk.js.LICENSE.txt
# 2022-06-11 20:01:02,967 changelog.txt
# 2022-06-11 20:01:02,983 ThirdPartyNotices.txt
# 2022-06-11 20:01:02,994 TableTextServiceArray.txt
# 2022-06-11 20:01:02,995 TableTextServiceDaYi.txt
# 2022-06-11 20:01:02,997 TableTextServiceTigrinya.txt
# 2022-06-11 20:01:02,998 TableTextServiceYi.txt
# 2022-06-11 20:01:03,052 index.txt
# 2022-06-11 20:01:03,110 LICENSE.txt
# 2022-06-11 20:01:03,129 nativePlugins.txt
# 2022-06-11 20:01:03,221 terms-condition.txt
# 2022-06-11 20:01:03,224 terms-condition.txt
# 2022-06-11 20:01:03,253 direct-link-template.txt
# 2022-06-11 20:01:03,254 multi-video-template.txt
# 2022-06-11 20:01:03,255 streaming-video-template.txt
# 2022-06-11 20:01:03,256 video-enhanced-template.txt
# 2022-06-11 20:01:03,844 ThirdPartyNotices.txt
# 2022-06-11 20:01:04,049 ExcelNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:04,995 OutlookAddrNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,004 OutlookApptNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,015 OutlookMailNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,046 OutlookMailReadNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,056 OutlookMeetingReqReadNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,066 OutlookMeetingReqSendNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,077 OutlookNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,083 OutlookTaskNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,086 WordNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,097 card_expiration_terms_dict.txt
# 2022-06-11 20:01:05,101 card_security_terms_dict.txt
# 2022-06-11 20:01:05,104 card_terms_dict.txt
# 2022-06-11 20:01:05,107 ssn_high_group_info.txt
# 2022-06-11 20:01:05,201 NOTICE.txt
# 2022-06-11 20:01:05,251 PowerPointNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,568 lpklegal.txt
# 2022-06-11 20:01:05,581 AccessRuntime2019_eula.txt
# 2022-06-11 20:01:05,583 AccessRuntime2021_eula.txt
# 2022-06-11 20:01:05,586 AccessRuntime_eula.txt
# 2022-06-11 20:01:05,589 Client2019_eula.txt
# 2022-06-11 20:01:05,591 Client2021_eula.txt
# 2022-06-11 20:01:05,594 ClientARMRefer2019_eula.txt
# 2022-06-11 20:01:05,596 ClientARMRefer_eula.txt
# 2022-06-11 20:01:05,598 ClientLangPack2019_eula.txt
# 2022-06-11 20:01:05,601 ClientLangPack2021_eula.txt
# 2022-06-11 20:01:05,603 ClientLangPack_eula.txt
# 2022-06-11 20:01:05,606 ClientOSub2019_eula.txt
# 2022-06-11 20:01:05,608 ClientOSub_eula.txt
# 2022-06-11 20:01:05,612 ClientPreview_eula.txt
# 2022-06-11 20:01:05,615 ClientSub2019_eula.txt
# 2022-06-11 20:01:05,620 ClientSub_eula.txt
# 2022-06-11 20:01:05,623 ClientSub_M365_eula.txt
# 2022-06-11 20:01:05,630 ClientVolumeLicense2019_eula.txt
# 2022-06-11 20:01:05,634 ClientVolumeLicense2021_eula.txt
# 2022-06-11 20:01:05,638 ClientVolumeLicense_eula.txt
# 2022-06-11 20:01:05,642 client_eula.txt
# 2022-06-11 20:01:05,646 LyncBasic_Eula.txt
# 2022-06-11 20:01:05,650 LyncVDI_Eula.txt
# 2022-06-11 20:01:05,654 SkypeForBusinessBasic2019_eula.txt
# 2022-06-11 20:01:05,657 SkypeForBusinessBasic2021_eula.txt
# 2022-06-11 20:01:05,663 SkypeForBusinessVDI2019_eula.txt
# 2022-06-11 20:01:05,670 SkypeForBusinessVDI2021_eula.txt
# 2022-06-11 20:01:05,674 smb_eula.txt
# 2022-06-11 20:01:05,678 WacLangPack2019Eula.txt
# 2022-06-11 20:01:05,683 WacLangPack2021Eula.txt
# 2022-06-11 20:01:05,689 WacLangPackEula.txt
# 2022-06-11 20:01:05,694 WordNaiveBayesCommandRanker.txt
# 2022-06-11 20:01:05,825 third-party-notices.txt
# 2022-06-11 20:01:05,829 card_expiration_terms_dict.txt
# 2022-06-11 20:01:05,832 card_security_terms_dict.txt
# 2022-06-11 20:01:05,834 card_terms_dict.txt
# 2022-06-11 20:01:05,836 ssn_high_group_info.txt
# 2022-06-11 20:01:05,852 TPN.txt
# 2022-06-11 20:01:05,856 TPN.txt
# 2022-06-11 20:01:05,862 ThirdPartyNotices.txt
# 2022-06-11 20:01:05,877 notice.txt
# 2022-06-11 20:01:05,898 cardview.win32.bundle.LICENSE.txt
# 2022-06-11 20:01:05,901 cardview.win32.bundle.tpn.txt
# 2022-06-11 20:01:05,938 index.win32.bundle.LICENSE.txt
# 2022-06-11 20:01:05,952 index.win32.bundle.LICENSE.txt
# 2022-06-11 20:01:05,955 index.win32.bundle.tpn.txt
# 2022-06-11 20:01:05,962 licensing.win32.bundle.LICENSE.txt
# 2022-06-11 20:01:05,965 subcenter.win32.bundle.LICENSE.txt
# 2022-06-11 20:01:05,981 build.txt
# 2022-06-11 20:01:05,983 robots.txt
# 2022-06-11 20:01:06,016 268.d70d014f.chunk.js.LICENSE.txt
# 2022-06-11 20:01:06,017 269.346b6196.chunk.js.LICENSE.txt
# 2022-06-11 20:01:06,019 270.f9c6bf4d.chunk.js.LICENSE.txt
# 2022-06-11 20:01:06,020 271.c8313a73.chunk.js.LICENSE.txt
# 2022-06-11 20:01:06,022 274.7db5d366.chunk.js.LICENSE.txt
# 2022-06-11 20:01:06,024 3.430651c5.chunk.js.LICENSE.txt
# 2022-06-11 20:01:06,026 FluidFramework-HashFallback.74e8affd.chunk.js.LICENSE.txt
# 2022-06-11 20:01:06,229 card_expiration_terms_dict.txt
# 2022-06-11 20:01:06,231 card_security_terms_dict.txt
# 2022-06-11 20:01:06,231 card_terms_dict.txt
# 2022-06-11 20:01:06,233 ssn_high_group_info.txt
# 2022-06-11 20:01:06,460 GCode.txt
# 2022-06-11 20:01:06,472 ReadMe.txt
# 2022-06-11 20:01:06,523 NOTICE.txt
# 2022-06-11 20:01:06,640 Third Party Notices.txt
# 2022-06-11 20:01:06,667 Third Party Notices.txt
# 2022-06-11 20:01:06,813 managedAssemblies.txt
# 2022-06-11 20:01:06,815 nativePlugins.txt
# 2022-06-11 20:01:07,079 ThirdPartyNotice.txt
# 2022-06-11 20:01:07,107 index.txt
# 2022-06-11 20:01:07,181 NOTICE.txt
# 2022-06-11 20:01:07,419 index.txt
# 2022-06-11 20:01:07,454 about_BeforeEach_AfterEach.help.txt
# 2022-06-11 20:01:07,456 about_Mocking.help.txt
# 2022-06-11 20:01:07,457 about_Pester.help.txt
# 2022-06-11 20:01:07,458 about_should.help.txt
# 2022-06-11 20:01:07,461 about_TestDrive.help.txt
# 2022-06-11 20:01:07,476 License.txt
# 2022-06-11 20:01:07,478 Rar.txt
# 2022-06-11 20:01:07,481 ReadMe.txt
# 2022-06-11 20:01:07,482 WhatsNew.txt
# 2022-06-11 20:01:07,500 hard_or_soft.txt
# 2022-06-11 20:01:07,503 meet_again.txt
# 2022-06-11 20:01:07,506 separate.txt
# 2022-06-11 20:01:07,507 separate_same_domain.txt
# 2022-06-11 20:01:07,519 LICENSE.txt
# 2022-06-11 20:01:07,567 LICENSE.txt
# 2022-06-11 20:01:07,576 LICENSE.txt
# 2022-06-11 20:01:08,669 LICENSE.txt
# 2022-06-11 20:01:08,684 hard_or_soft.txt
# 2022-06-11 20:01:08,686 meet_again.txt
# 2022-06-11 20:01:08,689 separate.txt
# 2022-06-11 20:01:08,691 separate_same_domain.txt
# 2022-06-11 20:01:08,711 LICENSE.txt
# 2022-06-11 20:01:08,749 LICENSE.txt
# 2022-06-11 20:01:08,878 LICENSE.txt
# 2022-06-11 20:01:08,927 LICENSE.txt
# 2022-06-11 20:01:09,671 ThirdPartyNotices.MSHWLatin.txt
# 2022-06-11 20:01:09,703 service_log.txt
# 2022-06-11 20:01:09,759 Contact.txt
# 2022-06-11 20:01:09,761 readme.txt
# 2022-06-11 20:01:10,026 AUTHORS.txt
# 2022-06-11 20:01:10,028 MIT-LICENSE.txt
# 2022-06-11 20:01:10,095 tld.txt
# 2022-06-11 20:01:10,112 ReadMe.txt
# 2022-06-11 20:01:10,135 MIT-LICENSE.txt
# 2022-06-11 20:01:10,153 ChangeLog.txt
# 2022-06-11 20:01:10,156 ChangeLog_jws322.txt
# 2022-06-11 20:01:10,157 LICENSE.txt
# 2022-06-11 20:01:10,172 THIRDPARTY_LICENSE.bitcoin.txt
# 2022-06-11 20:01:10,174 THIRDPARTY_LICENSE.cryptojs.txt
# 2022-06-11 20:01:10,176 THIRDPARTY_LICENSE.jsonsans.txt
# 2022-06-11 20:01:10,179 THIRDPARTY_LICENSE.pgp.txt
# 2022-06-11 20:01:10,181 THIRDPARTY_LICENSE.tomwu.txt
# 2022-06-11 20:01:10,184 THIRDPARTY_LICENSE.yui.txt
# 2022-06-11 20:01:10,187 THIRDPARTY_LICENSE.cryptojs.txt
# 2022-06-11 20:01:10,196 w3layouts-License.txt
# 2022-06-11 20:01:10,217 licenses.txt
# 2022-06-11 20:01:10,226 Readme.txt
# 2022-06-11 20:01:10,321 autofill_labeling_features.txt
# 2022-06-11 20:01:10,322 autofill_labeling_features_email.txt
# 2022-06-11 20:01:10,365 autofill_labeling_features.txt
# 2022-06-11 20:01:10,367 autofill_labeling_features_email.txt
# 2022-06-11 20:01:10,417 asan_blacklist.txt
# 2022-06-11 20:01:10,488 Copyright.txt
# 2022-06-11 20:01:10,498 DEVICE_LINK_OPTIONS.txt
# 2022-06-11 20:01:10,500 FIND_XXX.txt
# 2022-06-11 20:01:10,502 FIND_XXX_ORDER.txt
# 2022-06-11 20:01:10,504 FIND_XXX_ROOT.txt
# 2022-06-11 20:01:10,507 LINK_OPTIONS_LINKER.txt
# 2022-06-11 20:01:10,509 OPTIONS_SHELL.txt
# 2022-06-11 20:01:10,516 ENV_VAR.txt
# 2022-06-11 20:01:10,521 VS_TOOLSET_HOST_ARCH.txt
# 2022-06-11 20:01:10,524 COMPILE_DEFINITIONS_DISCLAIMER.txt
# 2022-06-11 20:01:10,528 INTERFACE_INCLUDE_DIRECTORIES_WARNING.txt
# 2022-06-11 20:01:10,530 INTERFACE_LINK_LIBRARIES_WARNING.txt
# 2022-06-11 20:01:10,535 ID_RESERVE.txt
# 2022-06-11 20:01:10,537 LINKS.txt
# 2022-06-11 20:01:10,538 OPTIONS_BUILD.txt
# 2022-06-11 20:01:10,543 OPTIONS_HELP.txt
# 2022-06-11 20:01:10,564 DEPRECATED.txt
# 2022-06-11 20:01:10,566 DISALLOWED_COMMAND.txt
# 2022-06-11 20:01:10,600 COMPILE_PDB_NOTE.txt
# 2022-06-11 20:01:10,602 CUDA_RUNTIME_LIBRARY-VALUES.txt
# 2022-06-11 20:01:10,604 INTERFACE_BUILD_PROPERTY.txt
# 2022-06-11 20:01:10,606 LINK_LIBRARIES_INDIRECTION.txt
# 2022-06-11 20:01:10,608 MSVC_RUNTIME_LIBRARY-VALUES.txt
# 2022-06-11 20:01:10,611 PDB_NOTE.txt
# 2022-06-11 20:01:10,613 XXX_OUTPUT_DIRECTORY.txt
# 2022-06-11 20:01:10,615 XXX_OUTPUT_NAME.txt
# 2022-06-11 20:01:10,619 dev.txt
# 2022-06-11 20:01:10,670 CMAKE_FIND_ROOT_PATH_MODE_XXX.txt
# 2022-06-11 20:01:10,671 CMAKE_OSX_VARIABLE.txt
# 2022-06-11 20:01:10,672 CTEST_CUSTOM_XXX.txt
# 2022-06-11 20:01:10,704 CMakeAddNewLanguage.txt
# 2022-06-11 20:01:10,707 readme.txt
# 2022-06-11 20:01:10,734 CMakeLists.txt
# 2022-06-11 20:01:10,738 CMakeLists.txt
# 2022-06-11 20:01:10,742 CMakeLists.txt
# 2022-06-11 20:01:10,774 CPack.GenericDescription.txt
# 2022-06-11 20:01:10,777 CPack.GenericLicense.txt
# 2022-06-11 20:01:10,779 CPack.GenericWelcome.txt
# 2022-06-11 20:01:10,962 about_NuGet.PackageManagement.PowerShellCmdlets.help.txt
# 2022-06-11 20:01:11,104 LICENSE.txt
# 2022-06-11 20:01:11,105 NOTICE.txt
# 2022-06-11 20:01:11,110 libexec-moved.txt
# 2022-06-11 20:01:11,112 package-versions.txt
# 2022-06-11 20:01:11,121 LICENSE.txt
# 2022-06-11 20:01:11,166 license.txt
# 2022-06-11 20:01:11,366 Swift.tmLanguage-license.txt
# 2022-06-11 20:01:11,370 Readme.txt
# 2022-06-11 20:01:11,467 Release Notes.txt
# 2022-06-11 20:01:11,469 ThirdPartyNotices.txt
# 2022-06-11 20:01:11,470 use.txt
# 2022-06-11 20:01:11,522 ReleaseNotes.txt
# 2022-06-11 20:01:11,524 ThirdPartyNotice.txt
# 2022-06-11 20:01:11,529 ThirdPartyNotice.txt
# 2022-06-11 20:01:11,553 ReleaseNotes.txt
# 2022-06-11 20:01:11,556 ThirdPartyNotices.txt
# 2022-06-11 20:01:11,673 JScriptLibraries.txt
# 2022-06-11 20:01:11,722 ThirdPartyNotices.txt
# 2022-06-11 20:01:11,769 ReleaseNotes.txt
# 2022-06-11 20:01:11,770 ThirdPartyNotices.txt
# 2022-06-11 20:01:11,773 use.txt
# 2022-06-11 20:01:11,843 CMakeLists.txt
# 2022-06-11 20:01:11,885 TextFile.txt
# 2022-06-11 20:01:11,935 CMakeLists.txt
# 2022-06-11 20:01:11,937 NoSubdirectoryCMakeLists.txt
# 2022-06-11 20:01:11,939 CMakeLists.txt
# 2022-06-11 20:01:12,021 text.txt
# 2022-06-11 20:01:12,118 ReadMe.txt
# 2022-06-11 20:01:12,144 Readme.txt
# 2022-06-11 20:01:12,152 Redist.txt
# 2022-06-11 20:01:12,154 ThirdPartyNotices.txt
# 2022-06-11 20:01:12,165 THIRDPARTYNOTICES.txt
# 2022-06-11 20:01:12,412 Microsoft.VCRedistVersion.default.txt
# 2022-06-11 20:01:12,415 Microsoft.VCToolsVersion.default.txt
# 2022-06-11 20:01:12,417 Microsoft.VCToolsVersion.v142.default.txt
# 2022-06-11 20:01:12,486 asan_blacklist.txt
# 2022-06-11 20:01:12,491 asan_blacklist.txt
# 2022-06-11 20:01:12,496 asan_blacklist.txt
# 2022-06-11 20:01:12,501 asan_blacklist.txt
# 2022-06-11 20:01:12,614 NOTICE.txt
# 2022-06-11 20:01:12,653 LICENSE.txt
# 2022-06-11 20:01:12,659 ThirdPartyNotices.txt
# 2022-06-11 20:01:12,686 LICENSE.txt
# 2022-06-11 20:01:12,699 License.txt
# 2022-06-11 20:01:12,700 thirdpartynotices.txt
# 2022-06-11 20:01:12,706 License.txt
# 2022-06-11 20:01:12,708 ThirdPartyNotices.txt
# 2022-06-11 20:01:12,726 LICENSE.txt
# 2022-06-11 20:01:12,732 LICENSE-MIT.txt
# 2022-06-11 20:01:12,744 LICENSE.txt
# 2022-06-11 20:01:12,753 LICENSE.txt
# 2022-06-11 20:01:12,851 Release Notes.txt
# 2022-06-11 20:01:12,868 Release Notes.txt
# 2022-06-11 20:01:12,873 Release Notes.txt
# 2022-06-11 20:01:12,888 rtldata.txt
# 2022-06-11 20:01:12,892 RtlS5Wake_Version.txt
# 2022-06-11 20:01:13,423 dualshock_4_brazilian.txt
# 2022-06-11 20:01:13,426 dualshock_4_bulgarian.txt
# 2022-06-11 20:01:13,428 dualshock_4_czech.txt
# 2022-06-11 20:01:13,430 dualshock_4_danish.txt
# 2022-06-11 20:01:13,433 dualshock_4_dutch.txt
# 2022-06-11 20:01:13,435 dualshock_4_english.txt
# 2022-06-11 20:01:13,437 dualshock_4_finnish.txt
# 2022-06-11 20:01:13,439 dualshock_4_french.txt
# 2022-06-11 20:01:13,442 dualshock_4_german.txt
# 2022-06-11 20:01:13,445 dualshock_4_greek.txt
# 2022-06-11 20:01:13,448 dualshock_4_hungarian.txt
# 2022-06-11 20:01:13,450 dualshock_4_italian.txt
# 2022-06-11 20:01:13,452 dualshock_4_japanese.txt
# 2022-06-11 20:01:13,454 dualshock_4_korean.txt
# 2022-06-11 20:01:13,456 dualshock_4_koreana.txt
# 2022-06-11 20:01:13,459 dualshock_4_latam.txt
# 2022-06-11 20:01:13,462 dualshock_4_norwegian.txt
# 2022-06-11 20:01:13,464 dualshock_4_polish.txt
# 2022-06-11 20:01:13,466 dualshock_4_portuguese.txt
# 2022-06-11 20:01:13,468 dualshock_4_romanian.txt
# 2022-06-11 20:01:13,470 dualshock_4_russian.txt
# 2022-06-11 20:01:13,473 dualshock_4_schinese.txt
# 2022-06-11 20:01:13,475 dualshock_4_spanish.txt
# 2022-06-11 20:01:13,477 dualshock_4_swedish.txt
# 2022-06-11 20:01:13,479 dualshock_4_tchinese.txt
# 2022-06-11 20:01:13,481 dualshock_4_thai.txt
# 2022-06-11 20:01:13,483 dualshock_4_turkish.txt
# 2022-06-11 20:01:13,485 dualshock_4_ukrainian.txt
# 2022-06-11 20:01:13,487 dualshock_4_vietnamese.txt
# 2022-06-11 20:01:13,489 steam_controller_brazilian.txt
# 2022-06-11 20:01:13,493 steam_controller_bulgarian.txt
# 2022-06-11 20:01:13,495 steam_controller_czech.txt
# 2022-06-11 20:01:13,497 steam_controller_danish.txt
# 2022-06-11 20:01:13,499 steam_controller_dutch.txt
# 2022-06-11 20:01:13,501 steam_controller_english.txt
# 2022-06-11 20:01:13,503 steam_controller_finnish.txt
# 2022-06-11 20:01:13,504 steam_controller_french.txt
# 2022-06-11 20:01:13,505 steam_controller_german.txt
# 2022-06-11 20:01:13,507 steam_controller_greek.txt
# 2022-06-11 20:01:13,510 steam_controller_hungarian.txt
# 2022-06-11 20:01:13,512 steam_controller_italian.txt
# 2022-06-11 20:01:13,515 steam_controller_japanese.txt
# 2022-06-11 20:01:13,517 steam_controller_korean.txt
# 2022-06-11 20:01:13,520 steam_controller_koreana.txt
# 2022-06-11 20:01:13,521 steam_controller_latam.txt
# 2022-06-11 20:01:13,524 steam_controller_norwegian.txt
# 2022-06-11 20:01:13,526 steam_controller_polish.txt
# 2022-06-11 20:01:13,528 steam_controller_portuguese.txt
# 2022-06-11 20:01:13,530 steam_controller_romanian.txt
# 2022-06-11 20:01:13,532 steam_controller_russian.txt
# 2022-06-11 20:01:13,535 steam_controller_schinese.txt
# 2022-06-11 20:01:13,538 steam_controller_spanish.txt
# 2022-06-11 20:01:13,541 steam_controller_swedish.txt
# 2022-06-11 20:01:13,544 steam_controller_tchinese.txt
# 2022-06-11 20:01:13,546 steam_controller_thai.txt
# 2022-06-11 20:01:13,547 steam_controller_turkish.txt
# 2022-06-11 20:01:13,549 steam_controller_ukrainian.txt
# 2022-06-11 20:01:13,552 steam_controller_vietnamese.txt
# 2022-06-11 20:01:13,555 switch_controller_brazilian.txt
# 2022-06-11 20:01:13,556 switch_controller_bulgarian.txt
# 2022-06-11 20:01:13,559 switch_controller_czech.txt
# 2022-06-11 20:01:13,560 switch_controller_danish.txt
# 2022-06-11 20:01:13,562 switch_controller_dutch.txt
# 2022-06-11 20:01:13,563 switch_controller_english.txt
# 2022-06-11 20:01:13,565 switch_controller_finnish.txt
# 2022-06-11 20:01:13,567 switch_controller_french.txt
# 2022-06-11 20:01:13,569 switch_controller_german.txt
# 2022-06-11 20:01:13,571 switch_controller_greek.txt
# 2022-06-11 20:01:13,573 switch_controller_hungarian.txt
# 2022-06-11 20:01:13,577 switch_controller_italian.txt
# 2022-06-11 20:01:13,579 switch_controller_japanese.txt
# 2022-06-11 20:01:13,581 switch_controller_korean.txt
# 2022-06-11 20:01:13,583 switch_controller_koreana.txt
# 2022-06-11 20:01:13,585 switch_controller_latam.txt
# 2022-06-11 20:01:13,587 switch_controller_norwegian.txt
# 2022-06-11 20:01:13,589 switch_controller_polish.txt
# 2022-06-11 20:01:13,592 switch_controller_portuguese.txt
# 2022-06-11 20:01:13,594 switch_controller_romanian.txt
# 2022-06-11 20:01:13,596 switch_controller_russian.txt
# 2022-06-11 20:01:13,598 switch_controller_schinese.txt
# 2022-06-11 20:01:13,600 switch_controller_spanish.txt
# 2022-06-11 20:01:13,601 switch_controller_swedish.txt
# 2022-06-11 20:01:13,603 switch_controller_tchinese.txt
# 2022-06-11 20:01:13,605 switch_controller_thai.txt
# 2022-06-11 20:01:13,607 switch_controller_turkish.txt
# 2022-06-11 20:01:13,610 switch_controller_ukrainian.txt
# 2022-06-11 20:01:13,612 switch_controller_vietnamese.txt
# 2022-06-11 20:01:13,614 xbox_360_brazilian.txt
# 2022-06-11 20:01:13,616 xbox_360_bulgarian.txt
# 2022-06-11 20:01:13,618 xbox_360_czech.txt
# 2022-06-11 20:01:13,619 xbox_360_danish.txt
# 2022-06-11 20:01:13,621 xbox_360_dutch.txt
# 2022-06-11 20:01:13,623 xbox_360_english.txt
# 2022-06-11 20:01:13,626 xbox_360_finnish.txt
# 2022-06-11 20:01:13,629 xbox_360_french.txt
# 2022-06-11 20:01:13,632 xbox_360_german.txt
# 2022-06-11 20:01:13,633 xbox_360_greek.txt
# 2022-06-11 20:01:13,635 xbox_360_hungarian.txt
# 2022-06-11 20:01:13,637 xbox_360_italian.txt
# 2022-06-11 20:01:13,638 xbox_360_japanese.txt
# 2022-06-11 20:01:13,640 xbox_360_korean.txt
# 2022-06-11 20:01:13,644 xbox_360_koreana.txt
# 2022-06-11 20:01:13,646 xbox_360_latam.txt
# 2022-06-11 20:01:13,648 xbox_360_norwegian.txt
# 2022-06-11 20:01:13,649 xbox_360_polish.txt
# 2022-06-11 20:01:13,651 xbox_360_portuguese.txt
# 2022-06-11 20:01:13,653 xbox_360_romanian.txt
# 2022-06-11 20:01:13,655 xbox_360_russian.txt
# 2022-06-11 20:01:13,657 xbox_360_schinese.txt
# 2022-06-11 20:01:13,658 xbox_360_spanish.txt
# 2022-06-11 20:01:13,660 xbox_360_swedish.txt
# 2022-06-11 20:01:13,661 xbox_360_tchinese.txt
# 2022-06-11 20:01:13,664 xbox_360_thai.txt
# 2022-06-11 20:01:13,665 xbox_360_turkish.txt
# 2022-06-11 20:01:13,667 xbox_360_ukrainian.txt
# 2022-06-11 20:01:13,669 xbox_360_vietnamese.txt
# 2022-06-11 20:01:13,670 xbox_one_brazilian.txt
# 2022-06-11 20:01:13,672 xbox_one_bulgarian.txt
# 2022-06-11 20:01:13,673 xbox_one_czech.txt
# 2022-06-11 20:01:13,676 xbox_one_danish.txt
# 2022-06-11 20:01:13,679 xbox_one_dutch.txt
# 2022-06-11 20:01:13,682 xbox_one_english.txt
# 2022-06-11 20:01:13,684 xbox_one_finnish.txt
# 2022-06-11 20:01:13,686 xbox_one_french.txt
# 2022-06-11 20:01:13,688 xbox_one_german.txt
# 2022-06-11 20:01:13,689 xbox_one_greek.txt
# 2022-06-11 20:01:13,691 xbox_one_hungarian.txt
# 2022-06-11 20:01:13,694 xbox_one_italian.txt
# 2022-06-11 20:01:13,696 xbox_one_japanese.txt
# 2022-06-11 20:01:13,697 xbox_one_korean.txt
# 2022-06-11 20:01:13,699 xbox_one_koreana.txt
# 2022-06-11 20:01:13,702 xbox_one_latam.txt
# 2022-06-11 20:01:13,704 xbox_one_norwegian.txt
# 2022-06-11 20:01:13,706 xbox_one_polish.txt
# 2022-06-11 20:01:13,709 xbox_one_portuguese.txt
# 2022-06-11 20:01:13,711 xbox_one_romanian.txt
# 2022-06-11 20:01:13,713 xbox_one_russian.txt
# 2022-06-11 20:01:13,715 xbox_one_schinese.txt
# 2022-06-11 20:01:13,717 xbox_one_spanish.txt
# 2022-06-11 20:01:13,719 xbox_one_swedish.txt
# 2022-06-11 20:01:13,720 xbox_one_tchinese.txt
# 2022-06-11 20:01:13,722 xbox_one_thai.txt
# 2022-06-11 20:01:13,724 xbox_one_turkish.txt
# 2022-06-11 20:01:13,728 xbox_one_ukrainian.txt
# 2022-06-11 20:01:13,731 xbox_one_vietnamese.txt
# 2022-06-11 20:01:13,777 trackerui_brazilian.txt
# 2022-06-11 20:01:13,779 trackerui_bulgarian.txt
# 2022-06-11 20:01:13,781 trackerui_czech.txt
# 2022-06-11 20:01:13,784 trackerui_danish.txt
# 2022-06-11 20:01:13,786 trackerui_dutch.txt
# 2022-06-11 20:01:13,788 trackerui_english.txt
# 2022-06-11 20:01:13,789 trackerui_finnish.txt
# 2022-06-11 20:01:13,792 trackerui_french.txt
# 2022-06-11 20:01:13,794 trackerui_german.txt
# 2022-06-11 20:01:13,797 trackerui_greek.txt
# 2022-06-11 20:01:13,799 trackerui_hungarian.txt
# 2022-06-11 20:01:13,801 trackerui_italian.txt
# 2022-06-11 20:01:13,803 trackerui_japanese.txt
# 2022-06-11 20:01:13,804 trackerui_korean.txt
# 2022-06-11 20:01:13,806 trackerui_koreana.txt
# 2022-06-11 20:01:13,808 trackerui_latam.txt
# 2022-06-11 20:01:13,811 trackerui_norwegian.txt
# 2022-06-11 20:01:13,812 trackerui_polish.txt
# 2022-06-11 20:01:13,814 trackerui_portuguese.txt
# 2022-06-11 20:01:13,816 trackerui_romanian.txt
# 2022-06-11 20:01:13,818 trackerui_russian.txt
# 2022-06-11 20:01:13,820 trackerui_schinese.txt
# 2022-06-11 20:01:13,822 trackerui_sc_schinese.txt
# 2022-06-11 20:01:13,824 trackerui_spanish.txt
# 2022-06-11 20:01:13,826 trackerui_swedish.txt
# 2022-06-11 20:01:13,828 trackerui_tchinese.txt
# 2022-06-11 20:01:13,829 trackerui_thai.txt
# 2022-06-11 20:01:13,831 trackerui_turkish.txt
# 2022-06-11 20:01:13,833 trackerui_ukrainian.txt
# 2022-06-11 20:01:13,835 trackerui_vietnamese.txt
# 2022-06-11 20:01:13,910 appinfo_log.previous.txt
# 2022-06-11 20:01:13,913 appinfo_log.txt
# 2022-06-11 20:01:13,915 bootstrap_log.txt
# 2022-06-11 20:01:13,917 cef_log.previous.txt
# 2022-06-11 20:01:13,918 cef_log.txt
# 2022-06-11 20:01:13,920 cloud_log.txt
# 2022-06-11 20:01:13,923 compat_log.previous.txt
# 2022-06-11 20:01:13,926 compat_log.txt
# 2022-06-11 20:01:13,929 configstore_log.previous.txt
# 2022-06-11 20:01:13,931 configstore_log.txt
# 2022-06-11 20:01:13,934 connection_log.previous.txt
# 2022-06-11 20:01:13,936 connection_log.txt
# 2022-06-11 20:01:13,937 content_log.previous.txt
# 2022-06-11 20:01:13,939 content_log.txt
# 2022-06-11 20:01:13,940 controller.txt
# 2022-06-11 20:01:13,944 controller_ui.txt
# 2022-06-11 20:01:13,946 inventory_service_log.txt
# 2022-06-11 20:01:13,948 librarysharing_log.txt
# 2022-06-11 20:01:13,949 parental_log.txt
# 2022-06-11 20:01:13,951 remote_connections.txt
# 2022-06-11 20:01:13,953 runprocess_log.txt
# 2022-06-11 20:01:13,954 shader_log.previous.txt
# 2022-06-11 20:01:13,956 shader_log.txt
# 2022-06-11 20:01:13,960 sitelicense_log.txt
# 2022-06-11 20:01:13,963 stats_log.txt
# 2022-06-11 20:01:13,965 steamui_system.previous.txt
# 2022-06-11 20:01:13,967 steamui_system.txt
# 2022-06-11 20:01:13,968 steamui_update.txt
# 2022-06-11 20:01:13,970 streaming_log.txt
# 2022-06-11 20:01:13,972 systemmanager.previous.txt
# 2022-06-11 20:01:13,974 systemmanager.txt
# 2022-06-11 20:01:13,978 timedtrial_log.txt
# 2022-06-11 20:01:13,979 webhelper.txt
# 2022-06-11 20:01:13,982 workshop_log.txt
# 2022-06-11 20:01:14,001 steambootstrapper_brazilian.txt
# 2022-06-11 20:01:14,005 steambootstrapper_bulgarian.txt
# 2022-06-11 20:01:14,007 steambootstrapper_czech.txt
# 2022-06-11 20:01:14,011 steambootstrapper_danish.txt
# 2022-06-11 20:01:14,014 steambootstrapper_dutch.txt
# 2022-06-11 20:01:14,016 steambootstrapper_english.txt
# 2022-06-11 20:01:14,017 steambootstrapper_finnish.txt
# 2022-06-11 20:01:14,019 steambootstrapper_french.txt
# 2022-06-11 20:01:14,021 steambootstrapper_german.txt
# 2022-06-11 20:01:14,023 steambootstrapper_greek.txt
# 2022-06-11 20:01:14,025 steambootstrapper_hungarian.txt
# 2022-06-11 20:01:14,027 steambootstrapper_italian.txt
# 2022-06-11 20:01:14,029 steambootstrapper_japanese.txt
# 2022-06-11 20:01:14,032 steambootstrapper_korean.txt
# 2022-06-11 20:01:14,035 steambootstrapper_koreana.txt
# 2022-06-11 20:01:14,037 steambootstrapper_latam.txt
# 2022-06-11 20:01:14,039 steambootstrapper_norwegian.txt
# 2022-06-11 20:01:14,041 steambootstrapper_polish.txt
# 2022-06-11 20:01:14,044 steambootstrapper_portuguese.txt
# 2022-06-11 20:01:14,046 steambootstrapper_romanian.txt
# 2022-06-11 20:01:14,048 steambootstrapper_russian.txt
# 2022-06-11 20:01:14,050 steambootstrapper_schinese.txt
# 2022-06-11 20:01:14,052 steambootstrapper_spanish.txt
# 2022-06-11 20:01:14,054 steambootstrapper_swedish.txt
# 2022-06-11 20:01:14,057 steambootstrapper_tchinese.txt
# 2022-06-11 20:01:14,059 steambootstrapper_thai.txt
# 2022-06-11 20:01:14,061 steambootstrapper_turkish.txt
# 2022-06-11 20:01:14,062 steambootstrapper_ukrainian.txt
# 2022-06-11 20:01:14,064 steambootstrapper_vietnamese.txt
# 2022-06-11 20:01:14,065 steamclean_brazilian.txt
# 2022-06-11 20:01:14,067 steamclean_czech.txt
# 2022-06-11 20:01:14,069 steamclean_danish.txt
# 2022-06-11 20:01:14,071 steamclean_dutch.txt
# 2022-06-11 20:01:14,072 steamclean_english.txt
# 2022-06-11 20:01:14,074 steamclean_finnish.txt
# 2022-06-11 20:01:14,076 steamclean_french.txt
# 2022-06-11 20:01:14,079 steamclean_german.txt
# 2022-06-11 20:01:14,082 steamclean_greek.txt
# 2022-06-11 20:01:14,084 steamclean_hungarian.txt
# 2022-06-11 20:01:14,087 steamclean_italian.txt
# 2022-06-11 20:01:14,089 steamclean_japanese.txt
# 2022-06-11 20:01:14,091 steamclean_korean.txt
# 2022-06-11 20:01:14,094 steamclean_norwegian.txt
# 2022-06-11 20:01:14,095 steamclean_polish.txt
# 2022-06-11 20:01:14,097 steamclean_portuguese.txt
# 2022-06-11 20:01:14,098 steamclean_romanian.txt
# 2022-06-11 20:01:14,100 steamclean_russian.txt
# 2022-06-11 20:01:14,102 steamclean_schinese.txt
# 2022-06-11 20:01:14,103 steamclean_spanish.txt
# 2022-06-11 20:01:14,105 steamclean_swedish.txt
# 2022-06-11 20:01:14,107 steamclean_tchinese.txt
# 2022-06-11 20:01:14,110 steamclean_thai.txt
# 2022-06-11 20:01:14,112 steamclean_turkish.txt
# 2022-06-11 20:01:14,115 steamclean_ukrainian.txt
# 2022-06-11 20:01:14,117 steamhtml_english.txt
# 2022-06-11 20:01:14,119 steamui_brazilian.txt
# 2022-06-11 20:01:14,121 steamui_bulgarian.txt
# 2022-06-11 20:01:14,122 steamui_czech.txt
# 2022-06-11 20:01:14,125 steamui_danish.txt
# 2022-06-11 20:01:14,126 steamui_dutch.txt
# 2022-06-11 20:01:14,128 steamui_english.txt
# 2022-06-11 20:01:14,130 steamui_finnish.txt
# 2022-06-11 20:01:14,133 steamui_french.txt
# 2022-06-11 20:01:14,135 steamui_german.txt
# 2022-06-11 20:01:14,137 steamui_greek.txt
# 2022-06-11 20:01:14,140 steamui_hungarian.txt
# 2022-06-11 20:01:14,142 steamui_italian.txt
# 2022-06-11 20:01:14,145 steamui_japanese.txt
# 2022-06-11 20:01:14,147 steamui_korean.txt
# 2022-06-11 20:01:14,149 steamui_koreana.txt
# 2022-06-11 20:01:14,151 steamui_latam.txt
# 2022-06-11 20:01:14,153 steamui_norwegian.txt
# 2022-06-11 20:01:14,156 steamui_pirate.txt
# 2022-06-11 20:01:14,158 steamui_polish.txt
# 2022-06-11 20:01:14,160 steamui_portuguese.txt
# 2022-06-11 20:01:14,162 steamui_postlogon_greek.txt
# 2022-06-11 20:01:14,164 steamui_romanian.txt
# 2022-06-11 20:01:14,166 steamui_russian.txt
# 2022-06-11 20:01:14,168 steamui_schinese.txt
# 2022-06-11 20:01:14,169 steamui_sc_schinese.txt
# 2022-06-11 20:01:14,171 steamui_spanish.txt
# 2022-06-11 20:01:14,172 steamui_swedish.txt
# 2022-06-11 20:01:14,175 steamui_tchinese.txt
# 2022-06-11 20:01:14,178 steamui_thai.txt
# 2022-06-11 20:01:14,180 steamui_turkish.txt
# 2022-06-11 20:01:14,182 steamui_ukrainian.txt
# 2022-06-11 20:01:14,184 steamui_vietnamese.txt
# 2022-06-11 20:01:14,186 url_list.txt
# 2022-06-11 20:01:14,208 overlay_brazilian.txt
# 2022-06-11 20:01:14,210 overlay_bulgarian.txt
# 2022-06-11 20:01:14,213 overlay_czech.txt
# 2022-06-11 20:01:14,214 overlay_danish.txt
# 2022-06-11 20:01:14,216 overlay_dutch.txt
# 2022-06-11 20:01:14,218 overlay_english.txt
# 2022-06-11 20:01:14,220 overlay_finnish.txt
# 2022-06-11 20:01:14,222 overlay_french.txt
# 2022-06-11 20:01:14,225 overlay_german.txt
# 2022-06-11 20:01:14,227 overlay_greek.txt
# 2022-06-11 20:01:14,229 overlay_hungarian.txt
# 2022-06-11 20:01:14,230 overlay_italian.txt
# 2022-06-11 20:01:14,232 overlay_japanese.txt
# 2022-06-11 20:01:14,234 overlay_korean.txt
# 2022-06-11 20:01:14,236 overlay_koreana.txt
# 2022-06-11 20:01:14,238 overlay_latam.txt
# 2022-06-11 20:01:14,241 overlay_norwegian.txt
# 2022-06-11 20:01:14,245 overlay_polish.txt
# 2022-06-11 20:01:14,246 overlay_portuguese.txt
# 2022-06-11 20:01:14,248 overlay_romanian.txt
# 2022-06-11 20:01:14,250 overlay_russian.txt
# 2022-06-11 20:01:14,251 overlay_schinese.txt
# 2022-06-11 20:01:14,253 overlay_sc_schinese.txt
# 2022-06-11 20:01:14,255 overlay_spanish.txt
# 2022-06-11 20:01:14,257 overlay_swedish.txt
# 2022-06-11 20:01:14,260 overlay_tchinese.txt
# 2022-06-11 20:01:14,263 overlay_thai.txt
# 2022-06-11 20:01:14,265 overlay_turkish.txt
# 2022-06-11 20:01:14,267 overlay_ukrainian.txt
# 2022-06-11 20:01:14,269 overlay_vietnamese.txt
# 2022-06-11 20:01:14,271 platform_brazilian.txt
# 2022-06-11 20:01:14,274 platform_bulgarian.txt
# 2022-06-11 20:01:14,277 platform_czech.txt
# 2022-06-11 20:01:14,279 platform_danish.txt
# 2022-06-11 20:01:14,281 platform_dutch.txt
# 2022-06-11 20:01:14,284 platform_english.txt
# 2022-06-11 20:01:14,286 platform_finnish.txt
# 2022-06-11 20:01:14,288 platform_french.txt
# 2022-06-11 20:01:14,290 platform_german.txt
# 2022-06-11 20:01:14,294 platform_greek.txt
# 2022-06-11 20:01:14,296 platform_hungarian.txt
# 2022-06-11 20:01:14,298 platform_italian.txt
# 2022-06-11 20:01:14,300 platform_japanese.txt
# 2022-06-11 20:01:14,301 platform_korean.txt
# 2022-06-11 20:01:14,304 platform_koreana.txt
# 2022-06-11 20:01:14,307 platform_latam.txt
# 2022-06-11 20:01:14,311 platform_norwegian.txt
# 2022-06-11 20:01:14,313 platform_polish.txt
# 2022-06-11 20:01:14,315 platform_portuguese.txt
# 2022-06-11 20:01:14,317 platform_romanian.txt
# 2022-06-11 20:01:14,319 platform_russian.txt
# 2022-06-11 20:01:14,321 platform_schinese.txt
# 2022-06-11 20:01:14,323 platform_sc_schinese.txt
# 2022-06-11 20:01:14,326 platform_spanish.txt
# 2022-06-11 20:01:14,328 platform_swedish.txt
# 2022-06-11 20:01:14,330 platform_tchinese.txt
# 2022-06-11 20:01:14,331 platform_thai.txt
# 2022-06-11 20:01:14,334 platform_turkish.txt
# 2022-06-11 20:01:14,335 platform_ukrainian.txt
# 2022-06-11 20:01:14,337 platform_vietnamese.txt
# 2022-06-11 20:01:14,339 vgui_brazilian.txt
# 2022-06-11 20:01:14,340 vgui_bulgarian.txt
# 2022-06-11 20:01:14,344 vgui_czech.txt
# 2022-06-11 20:01:14,346 vgui_danish.txt
# 2022-06-11 20:01:14,348 vgui_dutch.txt
# 2022-06-11 20:01:14,351 vgui_english.txt
# 2022-06-11 20:01:14,352 vgui_finnish.txt
# 2022-06-11 20:01:14,354 vgui_french.txt
# 2022-06-11 20:01:14,355 vgui_german.txt
# 2022-06-11 20:01:14,358 vgui_greek.txt
# 2022-06-11 20:01:14,360 vgui_hungarian.txt
# 2022-06-11 20:01:14,363 vgui_italian.txt
# 2022-06-11 20:01:14,365 vgui_japanese.txt
# 2022-06-11 20:01:14,367 vgui_korean.txt
# 2022-06-11 20:01:14,369 vgui_koreana.txt
# 2022-06-11 20:01:14,370 vgui_latam.txt
# 2022-06-11 20:01:14,373 vgui_norwegian.txt
# 2022-06-11 20:01:14,376 vgui_polish.txt
# 2022-06-11 20:01:14,378 vgui_portuguese.txt
# 2022-06-11 20:01:14,381 vgui_romanian.txt
# 2022-06-11 20:01:14,384 vgui_russian.txt
# 2022-06-11 20:01:14,385 vgui_schinese.txt
# 2022-06-11 20:01:14,387 vgui_sc_schinese.txt
# 2022-06-11 20:01:14,389 vgui_spanish.txt
# 2022-06-11 20:01:14,393 vgui_swedish.txt
# 2022-06-11 20:01:14,395 vgui_tchinese.txt
# 2022-06-11 20:01:14,398 vgui_thai.txt
# 2022-06-11 20:01:14,400 vgui_turkish.txt
# 2022-06-11 20:01:14,402 vgui_ukrainian.txt
# 2022-06-11 20:01:14,404 vgui_vietnamese.txt
# 2022-06-11 20:01:14,418 serverbrowser_brazilian.txt
# 2022-06-11 20:01:14,420 serverbrowser_bulgarian.txt
# 2022-06-11 20:01:14,421 serverbrowser_czech.txt
# 2022-06-11 20:01:14,422 serverbrowser_danish.txt
# 2022-06-11 20:01:14,424 serverbrowser_dutch.txt
# 2022-06-11 20:01:14,426 serverbrowser_english.txt
# 2022-06-11 20:01:14,428 serverbrowser_finnish.txt
# 2022-06-11 20:01:14,430 serverbrowser_french.txt
# 2022-06-11 20:01:14,432 serverbrowser_german.txt
# 2022-06-11 20:01:14,434 serverbrowser_greek.txt
# 2022-06-11 20:01:14,436 serverbrowser_hungarian.txt
# 2022-06-11 20:01:14,439 serverbrowser_italian.txt
# 2022-06-11 20:01:14,441 serverbrowser_japanese.txt
# 2022-06-11 20:01:14,445 serverbrowser_korean.txt
# 2022-06-11 20:01:14,447 serverbrowser_koreana.txt
# 2022-06-11 20:01:14,449 serverbrowser_latam.txt
# 2022-06-11 20:01:14,451 serverbrowser_norwegian.txt
# 2022-06-11 20:01:14,453 serverbrowser_polish.txt
# 2022-06-11 20:01:14,455 serverbrowser_portuguese.txt
# 2022-06-11 20:01:14,457 serverbrowser_romanian.txt
# 2022-06-11 20:01:14,459 serverbrowser_russian.txt
# 2022-06-11 20:01:14,461 serverbrowser_schinese.txt
# 2022-06-11 20:01:14,463 serverbrowser_sc_schinese.txt
# 2022-06-11 20:01:14,465 serverbrowser_spanish.txt
# 2022-06-11 20:01:14,468 serverbrowser_swedish.txt
# 2022-06-11 20:01:14,470 serverbrowser_tchinese.txt
# 2022-06-11 20:01:14,473 serverbrowser_thai.txt
# 2022-06-11 20:01:14,476 serverbrowser_turkish.txt
# 2022-06-11 20:01:14,479 serverbrowser_ukrainian.txt
# 2022-06-11 20:01:14,480 serverbrowser_vietnamese.txt
# 2022-06-11 20:01:14,499 steamui_postlogon_brazilian.txt
# 2022-06-11 20:01:14,502 steamui_postlogon_bulgarian.txt
# 2022-06-11 20:01:14,504 steamui_postlogon_czech.txt
# 2022-06-11 20:01:14,506 steamui_postlogon_danish.txt
# 2022-06-11 20:01:14,509 steamui_postlogon_dutch.txt
# 2022-06-11 20:01:14,511 steamui_postlogon_english.txt
# 2022-06-11 20:01:14,513 steamui_postlogon_finnish.txt
# 2022-06-11 20:01:14,514 steamui_postlogon_french.txt
# 2022-06-11 20:01:14,516 steamui_postlogon_german.txt
# 2022-06-11 20:01:14,517 steamui_postlogon_greek.txt
# 2022-06-11 20:01:14,519 steamui_postlogon_hungarian.txt
# 2022-06-11 20:01:14,521 steamui_postlogon_italian.txt
# 2022-06-11 20:01:14,523 steamui_postlogon_japanese.txt
# 2022-06-11 20:01:14,525 steamui_postlogon_korean.txt
# 2022-06-11 20:01:14,527 steamui_postlogon_koreana.txt
# 2022-06-11 20:01:14,529 steamui_postlogon_latam.txt
# 2022-06-11 20:01:14,531 steamui_postlogon_norwegian.txt
# 2022-06-11 20:01:14,535 steamui_postlogon_polish.txt
# 2022-06-11 20:01:14,537 steamui_postlogon_portuguese.txt
# 2022-06-11 20:01:14,539 steamui_postlogon_romanian.txt
# 2022-06-11 20:01:14,541 steamui_postlogon_russian.txt
# 2022-06-11 20:01:14,544 steamui_postlogon_schinese.txt
# 2022-06-11 20:01:14,545 steamui_postlogon_sc_schinese.txt
# 2022-06-11 20:01:14,547 steamui_postlogon_spanish.txt
# 2022-06-11 20:01:14,549 steamui_postlogon_swedish.txt
# 2022-06-11 20:01:14,551 steamui_postlogon_tchinese.txt
# 2022-06-11 20:01:14,554 steamui_postlogon_thai.txt
# 2022-06-11 20:01:14,556 steamui_postlogon_turkish.txt
# 2022-06-11 20:01:14,558 steamui_postlogon_ukrainian.txt
# 2022-06-11 20:01:14,560 steamui_postlogon_vietnamese.txt
# 2022-06-11 20:01:14,577 log.txt
# 2022-06-11 20:01:14,934 monof_tt-be11.txt
# 2022-06-11 20:01:14,935 SIL Open Font License.txt
# 2022-06-11 20:01:14,937 twemojimozilla.txt
# 2022-06-11 20:01:15,320 freeimage-license.txt
# 2022-06-11 20:01:15,322 steam_appid.txt
# 2022-06-11 20:01:15,324 uilog.txt
# 2022-06-11 20:01:15,335 freeimage-license.txt
# 2022-06-11 20:01:15,337 steam_appid.txt
# 2022-06-11 20:01:15,340 uilog.txt
# 2022-06-11 20:01:15,378 3rdpartylicenses.txt
# 2022-06-11 20:01:15,775 licenses.txt
# 2022-06-11 20:01:15,812 LICENSE_CJK.txt
# 2022-06-11 20:01:15,972 layout_brazilian_default.txt
# 2022-06-11 20:01:15,974 layout_brazilian_dualtouch.txt
# 2022-06-11 20:01:15,976 layout_danish_default.txt
# 2022-06-11 20:01:15,978 layout_danish_dualtouch.txt
# 2022-06-11 20:01:15,981 layout_dutch_default.txt
# 2022-06-11 20:01:15,983 layout_dutch_dualtouch.txt
# 2022-06-11 20:01:15,986 layout_english_default.txt
# 2022-06-11 20:01:15,988 layout_english_dualtouch.txt
# 2022-06-11 20:01:15,991 layout_finnish_default.txt
# 2022-06-11 20:01:15,993 layout_finnish_dualtouch.txt
# 2022-06-11 20:01:15,996 layout_french_default.txt
# 2022-06-11 20:01:15,998 layout_french_dualtouch.txt
# 2022-06-11 20:01:16,001 layout_german_default.txt
# 2022-06-11 20:01:16,003 layout_german_dualtouch.txt
# 2022-06-11 20:01:16,006 layout_hungarian_dualtouch.txt
# 2022-06-11 20:01:16,009 layout_italian_default.txt
# 2022-06-11 20:01:16,012 layout_italian_dualtouch.txt
# 2022-06-11 20:01:16,014 layout_norwegian_default.txt
# 2022-06-11 20:01:16,017 layout_norwegian_dualtouch.txt
# 2022-06-11 20:01:16,019 layout_polish_default.txt
# 2022-06-11 20:01:16,022 layout_polish_dualtouch.txt
# 2022-06-11 20:01:16,024 layout_portuguese_default.txt
# 2022-06-11 20:01:16,027 layout_portuguese_dualtouch.txt
# 2022-06-11 20:01:16,029 layout_romanian_dualtouch.txt
# 2022-06-11 20:01:16,031 layout_russian_default.txt
# 2022-06-11 20:01:16,032 layout_russian_dualtouch.txt
# 2022-06-11 20:01:16,035 layout_spanish_default.txt
# 2022-06-11 20:01:16,038 layout_spanish_dualtouch.txt
# 2022-06-11 20:01:16,041 layout_swedish_default.txt
# 2022-06-11 20:01:16,044 layout_swedish_dualtouch.txt
# 2022-06-11 20:01:16,047 layout_turkish_dualtouch.txt
# 2022-06-11 20:01:16,050 layout_ukrainian_dualtouch.txt
# 2022-06-11 20:01:16,095 tenfoot_brazilian.txt
# 2022-06-11 20:01:16,097 tenfoot_bulgarian.txt
# 2022-06-11 20:01:16,099 tenfoot_czech.txt
# 2022-06-11 20:01:16,101 tenfoot_danish.txt
# 2022-06-11 20:01:16,103 tenfoot_dutch.txt
# 2022-06-11 20:01:16,105 tenfoot_english.txt
# 2022-06-11 20:01:16,108 tenfoot_finnish.txt
# 2022-06-11 20:01:16,110 tenfoot_french.txt
# 2022-06-11 20:01:16,113 tenfoot_german.txt
# 2022-06-11 20:01:16,114 tenfoot_greek.txt
# 2022-06-11 20:01:16,116 tenfoot_hungarian.txt
# 2022-06-11 20:01:16,118 tenfoot_italian.txt
# 2022-06-11 20:01:16,120 tenfoot_japanese.txt
# 2022-06-11 20:01:16,123 tenfoot_korean.txt
# 2022-06-11 20:01:16,126 tenfoot_koreana.txt
# 2022-06-11 20:01:16,128 tenfoot_latam.txt
# 2022-06-11 20:01:16,130 tenfoot_norwegian.txt
# 2022-06-11 20:01:16,131 tenfoot_polish.txt
# ...
# 2022-06-11 20:01:52,338 INSTALL_00a6_b2b9f3ac-e835-4a0b-bd35-dae2678d28f2.txt
# 2022-06-11 20:01:52,339 INSTALL_00fb_0341b4c9-2dcc-43e1-9cc4-d0c682e0a258.txt
# 2022-06-11 20:01:52,340 INSTALL_00fe_f2b44090-b27f-4d17-80d0-044f675087b9.txt
# 2022-06-11 20:01:52,341 INSTALL_017f_6a12d8bc-3237-44b0-a5fa-60ca5bccc2db.txt
# 2022-06-11 20:01:52,342 INSTALL_032e_193fe09b-fd72-495d-b98e-ca5cd4f21e1c.txt
# 2022-06-11 20:01:52,343 INSTALL_0510_5f98975a-d4f9-4c94-920c-394b2193ab10.txt
# 2022-06-11 20:01:52,344 INSTALL_0524_5f98975a-d4f9-4c94-920c-394b2193ab10.txt
# 2022-06-11 20:01:52,345 INSTALL_ffff_0341b4c9-2dcc-43e1-9cc4-d0c682e0a258.txt
# 2022-06-11 20:01:52,345 INSTALL_ffff_39fcceea-c7d3-4722-8b2e-d194e17493fb.txt
# 2022-06-11 20:01:52,347 INSTALL_ffff_49fdc713-d81f-453f-b8a6-82f64f5b5de7.txt
# 2022-06-11 20:01:52,348 INSTALL_ffff_5ab848d5-18a5-4e44-b55b-23c7fb082583.txt
# 2022-06-11 20:01:52,349 INSTALL_ffff_5f98975a-d4f9-4c94-920c-394b2193ab10.txt
# 2022-06-11 20:01:52,350 INSTALL_ffff_6a12d8bc-3237-44b0-a5fa-60ca5bccc2db.txt
# 2022-06-11 20:01:52,352 INSTALL_ffff_83022c68-f139-43c0-8557-de076b2185cb.txt
# 2022-06-11 20:01:52,353 INSTALL_ffff_84c98382-2d72-43bc-8569-f7f3dda33ad0.txt
# 2022-06-11 20:01:52,354 INSTALL_ffff_87b43418-3d01-4889-aadb-389ffee68c9d.txt
# 2022-06-11 20:01:52,355 INSTALL_ffff_9aa2b8d9-b6ca-4b90-8684-04ce1d6d292d.txt
# 2022-06-11 20:01:52,356 INSTALL_ffff_b2b9f3ac-e835-4a0b-bd35-dae2678d28f2.txt
# 2022-06-11 20:01:52,357 INSTALL_ffff_d2a86716-ea12-4519-afb0-e140208801da.txt
# 2022-06-11 20:01:52,358 INSTALL_ffff_d58f48c2-7c50-4265-9de9-a1a229b11c66.txt
# 2022-06-11 20:01:52,359 INSTALL_ffff_d9503faa-ab2e-41d5-a422-57be00e0cf40.txt
# 2022-06-11 20:01:52,360 INSTALL_ffff_f2b44090-b27f-4d17-80d0-044f675087b9.txt
# 2022-06-11 20:01:52,361 INSTALL_ffff_f58988c7-6536-488f-b2b7-4d2454e2e4dc.txt
# 2022-06-11 20:01:52,362 INSTALL_ffff_fc3a6c63-83ff-4864-beda-d009073fb398.txt
# 2022-06-11 20:01:54,162 ThirdPartyNotices.txt
# 2022-06-11 20:01:54,206 ThirdPartyNotices.txt
# 2022-06-11 20:01:54,303 WER75EA.tmp.appcompat.txt
# 2022-06-11 20:01:59,118 license.txt
# 2022-06-11 20:01:59,135 vmchipset third-party notices.txt
# 2022-06-11 20:01:59,137 vmchipset third-party notices.txt
# 2022-06-11 20:02:03,350 hwcompat.txt
# 2022-06-11 20:02:03,352 hwcompat.txt
# 2022-06-11 20:02:03,355 hwcompat.txt
# 2022-06-11 20:02:03,357 hwexclude.txt
# 2022-06-11 20:02:03,360 hwcompat.txt
# 2022-06-11 20:02:03,361 hwexclude.txt
# 2022-06-11 20:02:03,566 idwbinfo.txt
# 2022-06-11 20:02:03,569 idwbinfo.txt
# 2022-06-11 20:02:06,129 livedomainlist.txt
# 2022-06-11 20:02:06,132 livedomainlist.txt
# 2022-06-11 20:02:07,773 1.txt
# 2022-06-11 20:02:07,775 10.txt
# 2022-06-11 20:02:07,776 11.txt
# 2022-06-11 20:02:07,778 12.txt
# 2022-06-11 20:02:07,781 13.txt
# 2022-06-11 20:02:07,782 14.txt
# 2022-06-11 20:02:07,784 15.txt
# 2022-06-11 20:02:07,786 16.txt
# 2022-06-11 20:02:07,787 17.txt
# 2022-06-11 20:02:07,790 18.txt
# 2022-06-11 20:02:07,792 19.txt
# 2022-06-11 20:02:07,794 2.txt
# 2022-06-11 20:02:07,795 20.txt
# 2022-06-11 20:02:07,798 21.txt
# 2022-06-11 20:02:07,800 22.txt
# 2022-06-11 20:02:07,801 23.txt
# 2022-06-11 20:02:07,803 24.txt
# 2022-06-11 20:02:07,805 25.txt
# 2022-06-11 20:02:07,807 26.txt
# 2022-06-11 20:02:07,809 3.txt
# 2022-06-11 20:02:07,810 4.txt
# 2022-06-11 20:02:07,811 5.txt
# 2022-06-11 20:02:07,815 6.txt
# 2022-06-11 20:02:07,817 7.txt
# 2022-06-11 20:02:07,819 8.txt
# 2022-06-11 20:02:07,820 9.txt
# 2022-06-11 20:02:07,823 1.txt
# 2022-06-11 20:02:07,825 10.txt
# 2022-06-11 20:02:07,826 11.txt
# 2022-06-11 20:02:07,828 12.txt
# 2022-06-11 20:02:07,832 13.txt
# 2022-06-11 20:02:07,834 14.txt
# 2022-06-11 20:02:07,836 15.txt
# 2022-06-11 20:02:07,837 16.txt
# 2022-06-11 20:02:07,840 17.txt
# 2022-06-11 20:02:07,842 18.txt
# 2022-06-11 20:02:07,845 19.txt
# 2022-06-11 20:02:07,847 2.txt
# 2022-06-11 20:02:07,848 20.txt
# 2022-06-11 20:02:07,850 21.txt
# 2022-06-11 20:02:07,852 22.txt
# 2022-06-11 20:02:07,853 23.txt
# 2022-06-11 20:02:07,856 24.txt
# 2022-06-11 20:02:07,857 25.txt
# 2022-06-11 20:02:07,859 26.txt
# 2022-06-11 20:02:07,861 3.txt
# 2022-06-11 20:02:07,862 4.txt
# 2022-06-11 20:02:07,864 5.txt
# 2022-06-11 20:02:07,866 6.txt
# 2022-06-11 20:02:07,867 7.txt
# 2022-06-11 20:02:07,869 8.txt
# 2022-06-11 20:02:07,871 9.txt
# 2022-06-11 20:02:10,054 windowscodecsraw.txt
# 2022-06-11 20:02:10,056 windowscodecsraw.txt
# 2022-06-11 20:02:10,637 asdclassifiermodel.txt
# 2022-06-11 20:02:10,639 asdclassifiermodelnodepth.txt
# 2022-06-11 20:02:10,641 cnnmodel.txt
# 2022-06-11 20:02:10,655 asdclassifiermodel.txt
# 2022-06-11 20:02:10,657 asdclassifiermodelnodepth.txt
# 2022-06-11 20:02:10,659 cnnmodel.txt
# 2022-06-11 20:02:10,968 thirdpartynotices.txt
# 2022-06-11 20:02:10,970 thirdpartynotices.txt
# 2022-06-11 20:02:11,163 thirdpartynoticesbyshs.txt
# 2022-06-11 20:02:12,604 livedomainlist.txt
# 2022-06-11 20:02:12,606 livedomainlist.txt
# 2022-06-11 20:02:13,686 windowscodecsraw.txt
# 2022-06-11 20:02:13,689 windowscodecsraw.txt
# 2022-06-11 20:02:19,789 license.txt
# 2022-06-11 20:02:19,808 vmchipset third-party notices.txt
# 2022-06-11 20:02:19,811 vmchipset third-party notices.txt
# 2022-06-11 20:02:22,641 hwcompat.txt
# 2022-06-11 20:02:22,643 hwcompat.txt
# 2022-06-11 20:02:22,647 hwcompat.txt
# 2022-06-11 20:02:22,650 hwexclude.txt
# 2022-06-11 20:02:22,654 hwcompat.txt
# 2022-06-11 20:02:22,660 hwexclude.txt
# 2022-06-11 20:02:22,866 idwbinfo.txt
# 2022-06-11 20:02:22,868 idwbinfo.txt
# 2022-06-11 20:02:24,890 livedomainlist.txt
# 2022-06-11 20:02:24,891 livedomainlist.txt
# 2022-06-11 20:02:26,299 26.txt
# 2022-06-11 20:02:26,300 5.txt
# 2022-06-11 20:02:26,301 8.txt
# 2022-06-11 20:02:26,304 26.txt
# 2022-06-11 20:02:26,307 5.txt
# 2022-06-11 20:02:26,309 8.txt
# 2022-06-11 20:02:28,106 windowscodecsraw.txt
# 2022-06-11 20:02:28,108 windowscodecsraw.txt
# 2022-06-11 20:02:28,662 asdclassifiermodel.txt
# 2022-06-11 20:02:28,663 asdclassifiermodelnodepth.txt
# 2022-06-11 20:02:28,664 cnnmodel.txt
# 2022-06-11 20:02:28,679 asdclassifiermodel.txt
# 2022-06-11 20:02:28,681 asdclassifiermodelnodepth.txt
# 2022-06-11 20:02:28,682 cnnmodel.txt
# 2022-06-11 20:02:28,944 thirdpartynotices.txt
# 2022-06-11 20:02:28,946 thirdpartynotices.txt
# 2022-06-11 20:02:29,113 thirdpartynoticesbyshs.txt
# 2022-06-11 20:02:30,139 livedomainlist.txt
# 2022-06-11 20:02:30,142 livedomainlist.txt
# 2022-06-11 20:02:30,917 windowscodecsraw.txt
# 2022-06-11 20:02:30,919 windowscodecsraw.txt
# 2022-06-11 20:02:33,997 ThirdPartyNoticesBySHS.txt
# 2022-06-11 20:02:33,998 VmChipset Third-Party Notices.txt
# 2022-06-11 20:02:34,000 WindowsCodecsRaw.txt
# 2022-06-11 20:02:34,023 dberr.txt
# 2022-06-11 20:02:34,032 BullseyeCoverageError.txt
# 2022-06-11 20:02:36,832 gmreadme.txt
# 2022-06-11 20:02:36,833 rtldata.txt
# 2022-06-11 20:02:37,064 rtldata.txt
# 2022-06-11 20:02:37,066 rtldata.txt
# 2022-06-11 20:02:37,070 rtldata.txt
# 2022-06-11 20:02:37,072 rtldata.txt
# 2022-06-11 20:02:37,268 LiveDomainList.txt
# 2022-06-11 20:02:37,664 default.help.txt
# 2022-06-11 20:02:37,969 1.txt
# 2022-06-11 20:02:37,973 10.txt
# 2022-06-11 20:02:37,976 11.txt
# 2022-06-11 20:02:37,979 12.txt
# 2022-06-11 20:02:37,983 13.txt
# 2022-06-11 20:02:37,986 14.txt
# 2022-06-11 20:02:37,990 15.txt
# 2022-06-11 20:02:37,993 16.txt
# 2022-06-11 20:02:37,994 17.txt
# 2022-06-11 20:02:37,997 18.txt
# 2022-06-11 20:02:38,000 19.txt
# 2022-06-11 20:02:38,003 2.txt
# 2022-06-11 20:02:38,005 20.txt
# 2022-06-11 20:02:38,007 21.txt
# 2022-06-11 20:02:38,009 22.txt
# 2022-06-11 20:02:38,011 23.txt
# 2022-06-11 20:02:38,013 24.txt
# 2022-06-11 20:02:38,016 25.txt
# 2022-06-11 20:02:38,018 26.txt
# 2022-06-11 20:02:38,020 27.txt
# 2022-06-11 20:02:38,024 28.txt
# 2022-06-11 20:02:38,026 29.txt
# 2022-06-11 20:02:38,029 3.txt
# 2022-06-11 20:02:38,032 4.txt
# 2022-06-11 20:02:38,036 5.txt
# 2022-06-11 20:02:38,040 6.txt
# 2022-06-11 20:02:38,043 7.txt
# 2022-06-11 20:02:38,046 8.txt
# 2022-06-11 20:02:38,048 9.txt
# 2022-06-11 20:02:38,346 WindowsCodecsRaw.txt
# 2022-06-11 20:02:38,408 gmreadme.txt
# 2022-06-11 20:02:38,469 LiveDomainList.txt
# 2022-06-11 20:02:38,518 default.help.txt
# 2022-06-11 20:02:40,150 License.txt
# 2022-06-11 20:02:40,178 VmChipset Third-Party Notices.txt
# 2022-06-11 20:02:40,182 VmChipset Third-Party Notices.txt
# 2022-06-11 20:02:43,493 LiveDomainList.txt
# 2022-06-11 20:02:44,544 default.help.txt
# 2022-06-11 20:02:45,725 1.txt
# 2022-06-11 20:02:45,726 10.txt
# 2022-06-11 20:02:45,728 11.txt
# 2022-06-11 20:02:45,730 12.txt
# 2022-06-11 20:02:45,731 13.txt
# 2022-06-11 20:02:45,732 14.txt
# 2022-06-11 20:02:45,733 15.txt
# 2022-06-11 20:02:45,735 16.txt
# 2022-06-11 20:02:45,736 17.txt
# 2022-06-11 20:02:45,737 18.txt
# 2022-06-11 20:02:45,738 19.txt
# 2022-06-11 20:02:45,739 2.txt
# 2022-06-11 20:02:45,741 20.txt
# 2022-06-11 20:02:45,742 21.txt
# 2022-06-11 20:02:45,743 22.txt
# 2022-06-11 20:02:45,744 23.txt
# 2022-06-11 20:02:45,746 24.txt
# 2022-06-11 20:02:45,747 25.txt
# 2022-06-11 20:02:45,749 26.txt
# 2022-06-11 20:02:45,750 27.txt
# 2022-06-11 20:02:45,751 28.txt
# 2022-06-11 20:02:45,753 29.txt
# 2022-06-11 20:02:45,754 3.txt
# 2022-06-11 20:02:45,755 4.txt
# 2022-06-11 20:02:45,756 5.txt
# 2022-06-11 20:02:45,757 6.txt
# 2022-06-11 20:02:45,758 7.txt
# 2022-06-11 20:02:45,759 8.txt
# 2022-06-11 20:02:45,760 9.txt
# 2022-06-11 20:02:45,763 1.txt
# 2022-06-11 20:02:45,764 10.txt
# 2022-06-11 20:02:45,765 11.txt
# 2022-06-11 20:02:45,766 12.txt
# 2022-06-11 20:02:45,767 13.txt
# 2022-06-11 20:02:45,769 14.txt
# 2022-06-11 20:02:45,770 15.txt
# 2022-06-11 20:02:45,771 16.txt
# 2022-06-11 20:02:45,772 17.txt
# 2022-06-11 20:02:45,773 18.txt
# 2022-06-11 20:02:45,774 19.txt
# 2022-06-11 20:02:45,775 2.txt
# 2022-06-11 20:02:45,777 20.txt
# 2022-06-11 20:02:45,778 21.txt
# 2022-06-11 20:02:45,779 22.txt
# 2022-06-11 20:02:45,781 23.txt
# 2022-06-11 20:02:45,782 24.txt
# 2022-06-11 20:02:45,783 25.txt
# 2022-06-11 20:02:45,784 26.txt
# 2022-06-11 20:02:45,785 3.txt
# 2022-06-11 20:02:45,787 4.txt
# 2022-06-11 20:02:45,788 5.txt
# 2022-06-11 20:02:45,789 6.txt
# 2022-06-11 20:02:45,790 7.txt
# 2022-06-11 20:02:45,792 8.txt
# 2022-06-11 20:02:45,793 9.txt
# 2022-06-11 20:02:45,795 1.txt
# 2022-06-11 20:02:45,796 10.txt
# 2022-06-11 20:02:45,797 11.txt
# 2022-06-11 20:02:45,799 12.txt
# 2022-06-11 20:02:45,800 13.txt
# 2022-06-11 20:02:45,801 14.txt
# 2022-06-11 20:02:45,802 15.txt
# 2022-06-11 20:02:45,803 16.txt
# 2022-06-11 20:02:45,804 17.txt
# 2022-06-11 20:02:45,806 18.txt
# 2022-06-11 20:02:45,807 19.txt
# 2022-06-11 20:02:45,808 2.txt
# 2022-06-11 20:02:45,809 20.txt
# 2022-06-11 20:02:45,810 21.txt
# 2022-06-11 20:02:45,811 22.txt
# 2022-06-11 20:02:45,812 23.txt
# 2022-06-11 20:02:45,814 24.txt
# 2022-06-11 20:02:45,816 25.txt
# 2022-06-11 20:02:45,817 26.txt
# 2022-06-11 20:02:45,818 3.txt
# 2022-06-11 20:02:45,820 4.txt
# 2022-06-11 20:02:45,821 5.txt
# 2022-06-11 20:02:45,822 6.txt
# 2022-06-11 20:02:45,823 7.txt
# 2022-06-11 20:02:45,825 8.txt
# 2022-06-11 20:02:45,826 9.txt
# 2022-06-11 20:02:45,828 1.txt
# 2022-06-11 20:02:45,829 10.txt
# 2022-06-11 20:02:45,831 11.txt
# 2022-06-11 20:02:45,832 12.txt
# 2022-06-11 20:02:45,833 13.txt
# 2022-06-11 20:02:45,834 14.txt
# 2022-06-11 20:02:45,835 15.txt
# 2022-06-11 20:02:45,836 16.txt
# 2022-06-11 20:02:45,837 17.txt
# 2022-06-11 20:02:45,839 18.txt
# 2022-06-11 20:02:45,840 19.txt
# 2022-06-11 20:02:45,841 2.txt
# 2022-06-11 20:02:45,842 20.txt
# 2022-06-11 20:02:45,844 21.txt
# 2022-06-11 20:02:45,845 22.txt
# 2022-06-11 20:02:45,846 23.txt
# 2022-06-11 20:02:45,847 24.txt
# 2022-06-11 20:02:45,849 25.txt
# 2022-06-11 20:02:45,851 26.txt
# 2022-06-11 20:02:45,853 27.txt
# 2022-06-11 20:02:45,855 28.txt
# 2022-06-11 20:02:45,856 29.txt
# 2022-06-11 20:02:45,858 3.txt
# 2022-06-11 20:02:45,860 4.txt
# 2022-06-11 20:02:45,861 5.txt
# 2022-06-11 20:02:45,863 6.txt
# 2022-06-11 20:02:45,865 7.txt
# 2022-06-11 20:02:45,866 8.txt
# 2022-06-11 20:02:45,867 9.txt
# 2022-06-11 20:02:45,870 1.txt
# 2022-06-11 20:02:45,871 10.txt
# 2022-06-11 20:02:45,872 11.txt
# 2022-06-11 20:02:45,873 12.txt
# 2022-06-11 20:02:45,875 13.txt
# 2022-06-11 20:02:45,877 14.txt
# 2022-06-11 20:02:45,878 15.txt
# 2022-06-11 20:02:45,879 16.txt
# 2022-06-11 20:02:45,880 17.txt
# 2022-06-11 20:02:45,881 18.txt
# 2022-06-11 20:02:45,882 19.txt
# 2022-06-11 20:02:45,883 2.txt
# 2022-06-11 20:02:45,885 20.txt
# 2022-06-11 20:02:45,886 21.txt
# 2022-06-11 20:02:45,887 22.txt
# 2022-06-11 20:02:45,888 23.txt
# 2022-06-11 20:02:45,889 24.txt
# 2022-06-11 20:02:45,890 25.txt
# 2022-06-11 20:02:45,891 26.txt
# 2022-06-11 20:02:45,892 3.txt
# 2022-06-11 20:02:45,893 4.txt
# 2022-06-11 20:02:45,894 5.txt
# 2022-06-11 20:02:45,896 6.txt
# 2022-06-11 20:02:45,897 7.txt
# 2022-06-11 20:02:45,898 8.txt
# 2022-06-11 20:02:45,899 9.txt
# 2022-06-11 20:02:45,902 1.txt
# 2022-06-11 20:02:45,903 10.txt
# 2022-06-11 20:02:45,905 11.txt
# 2022-06-11 20:02:45,906 12.txt
# 2022-06-11 20:02:45,907 13.txt
# 2022-06-11 20:02:45,909 14.txt
# 2022-06-11 20:02:45,910 15.txt
# 2022-06-11 20:02:45,912 16.txt
# 2022-06-11 20:02:45,913 17.txt
# 2022-06-11 20:02:45,915 18.txt
# 2022-06-11 20:02:45,916 19.txt
# 2022-06-11 20:02:45,917 2.txt
# 2022-06-11 20:02:45,919 20.txt
# 2022-06-11 20:02:45,920 21.txt
# 2022-06-11 20:02:45,921 22.txt
# 2022-06-11 20:02:45,922 23.txt
# 2022-06-11 20:02:45,924 24.txt
# 2022-06-11 20:02:45,925 25.txt
# 2022-06-11 20:02:45,926 26.txt
# 2022-06-11 20:02:45,927 3.txt
# 2022-06-11 20:02:45,928 4.txt
# 2022-06-11 20:02:45,930 5.txt
# 2022-06-11 20:02:45,931 6.txt
# 2022-06-11 20:02:45,932 7.txt
# 2022-06-11 20:02:45,933 8.txt
# 2022-06-11 20:02:45,934 9.txt
# 2022-06-11 20:02:46,703 ThirdPartyNotices.MSHWLatin.txt
# 2022-06-11 20:02:46,748 TableTextServiceTigrinya.txt
# 2022-06-11 20:02:46,765 TableTextServiceArray.txt
# 2022-06-11 20:02:46,841 TableTextServiceYi.txt
# 2022-06-11 20:02:46,861 TableTextServiceDaYi.txt
# 2022-06-11 20:02:47,036 SBCModel.txt
# 2022-06-11 20:02:47,420 WindowsCodecsRaw.txt
# 2022-06-11 20:02:47,632 about_BeforeEach_AfterEach.help.txt
# 2022-06-11 20:02:47,633 about_Mocking.help.txt
# 2022-06-11 20:02:47,635 about_Pester.help.txt
# 2022-06-11 20:02:47,637 about_should.help.txt
# 2022-06-11 20:02:47,639 about_TestDrive.help.txt
# 2022-06-11 20:02:47,716 gmreadme.txt
# 2022-06-11 20:02:47,858 ThirdPartyNotices.txt
# 2022-06-11 20:02:48,164 ThirdPartyNotices.txt
# 2022-06-11 20:02:48,234 ThirdPartyNoticesBySHS.txt
# 2022-06-11 20:02:48,236 ThirdPartyNoticesBySHS.txt
# 2022-06-11 20:02:48,239 ThirdPartyNoticesBySHS.txt
# 2022-06-11 20:02:48,242 ThirdPartyNoticesBySHS.txt
# 2022-06-11 20:03:05,270 LiveDomainList.txt
# 2022-06-11 20:03:05,625 default.help.txt
# 2022-06-11 20:03:06,076 ThirdPartyNotices.MSHWLatin.txt
# 2022-06-11 20:03:06,096 TableTextServiceTigrinya.txt
# 2022-06-11 20:03:06,104 TableTextServiceArray.txt
# 2022-06-11 20:03:06,122 TableTextServiceYi.txt
# 2022-06-11 20:03:06,138 TableTextServiceDaYi.txt
# 2022-06-11 20:03:06,304 WindowsCodecsRaw.txt
# 2022-06-11 20:03:06,418 about_BeforeEach_AfterEach.help.txt
# 2022-06-11 20:03:06,420 about_Mocking.help.txt
# 2022-06-11 20:03:06,422 about_Pester.help.txt
# 2022-06-11 20:03:06,424 about_should.help.txt
# 2022-06-11 20:03:06,426 about_TestDrive.help.txt
# 2022-06-11 20:03:06,444 gmreadme.txt
# 2022-06-11 20:03:07,083 ThirdPartyNotices.txt
# 2022-06-11 20:03:07,185 hwcompatShared.txt
# 2022-06-11 20:03:07,188 hwcompat.txt
# 2022-06-11 20:03:07,189 hwexclude.txt
# 2022-06-11 20:03:07,191 hwcompat.txt
# 2022-06-11 20:03:07,192 hwexclude.txt
# 2022-06-11 20:03:07,199 search results generated!
# 2022-06-11 20:03:07,200 -------------------------
# 2022-06-11 20:03:49,176 'utf-8' codec can't decode byte 0xbc in position 2: invalid start byte
# 2022-06-11 20:04:10,910 Drive E is being scanned..
# 2022-06-11 20:04:10,911 generating search results...
# 2022-06-11 20:04:10,915 new sample.txt
# 2022-06-11 20:04:11,001 AhaShare.com.txt
# 2022-06-11 20:04:11,003 Torrent downloaded from Demonoid.com - Copy.txt
# 2022-06-11 20:04:11,005 Torrent Downloaded From ExtraTorrent.com.txt
# 2022-06-11 20:04:11,007 new sample.txt
# 2022-06-11 20:04:11,010 sample_1.txt
# 2022-06-11 20:04:11,012 sample_10.txt
# 2022-06-11 20:04:11,014 sample_2.txt
# 2022-06-11 20:04:11,016 sample_3.txt
# 2022-06-11 20:04:11,019 sample_4.txt
# 2022-06-11 20:04:11,022 sample_5.txt
# 2022-06-11 20:04:11,024 sample_6.txt
# 2022-06-11 20:04:11,027 sample_7.txt
# 2022-06-11 20:04:11,030 sample_8.txt
# 2022-06-11 20:04:11,032 sample_9.txt
# 2022-06-11 20:04:11,046 search results generated!
# 2022-06-11 20:04:11,048 -------------------------
# 2022-06-11 20:04:14,547 Merged '.txt' is ready! You can check it now.
